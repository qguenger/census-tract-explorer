# %% [markdown]
# # Middle Neighborhood Analysis in Pittsburgh

# %%
import pandas as pd
import numpy as np

# %%
middle_neighborhoods = pd.read_excel("LTDB_AlleghenyPA.XLSX", sheet_name=None)

# %%
middle_neighborhoods.keys()
# Out:
# dict_keys(['Data70', 'Data80', 'Data90', 'Data00', 'Data12', 'Data22', 'Variables'])

# %%
variables = middle_neighborhoods['Variables']
middle_neighborhoods.pop('Variables')
variables
# Out:
#     Tract Identification Variables (Census 2020 Boundaries)  \
# 0                                                 Name
# 1                                              tractid
# 2                                                tract
# 3                                                state
# 4                                               county
# ..                                                 ...
# 101                                             ag15up
# 102                                                mar
# 103                                                wds
# 104                                             family
# 105                                                fhh
#
#                                   Unnamed: 1  \
# 0                                Description
# 1                                Tract GEOID
# 2                                 Tract name
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 101             Population 15 years and over
# 102  Currently married (excluding separated)
# 103         Widowed, divorced, and separated
# 104                           Total families
# 105     Female-headed families with children
#
#                                             Unnamed: 2
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 101  This serves as the universe for tabulation of ...
# 102                                                NaN
# 103  The count is the sum of men and women in the c...
# 104  This variable serves as the denominator for ca...
# 105  In 1970, it is “Family with female head, own c...
#
# [106 rows x 3 columns]

# %%
var_dict = variables[['Tract Identification Variables (Census 2020 Boundaries)', 'Unnamed: 1']].set_index(\
    'Tract Identification Variables (Census 2020 Boundaries)').to_dict()['Unnamed: 1']
var_dict
# Out:
# {'Name': 'Description',
#  'tractid': 'Tract GEOID',
#  'tract': 'Tract name',
#  'state': nan,
#  'county': nan,
#  'placefp': 'Place FIPS code',
#  'placename': nan,
#  'cbsafp': 'CBSA FIPS code',
#  'cbsaname': nan,
#  'cbsatype': 'Metropolitan (MSA) or micropolitan (µsa)',
#  'countytype': 'Central or Outlying',
#  'metdivfp': 'Metropolitan division FIPS code',
#  'metdivname': nan,
#  'Census Variables': nan,
#  'micbsa': 'CBSA median income (2022$)',
#  'micity': 'Principal city median income (2022$)',
#  'pop': 'Total population',
#  'nhwht': 'Persons of white race, not Hispanic origin',
#  'nhblk': 'Persons of black race, not Hispanic origin',
#  'hisp': 'Persons of Hispanic origin',
#  'ntv': 'Persons of Native American race',
#  'asian': 'Persons of Asian race (and Pacific Islander)',
#  'agewht': 'White population with known age distribution',
#  'a15wht': '0-15 years old of white race',
#  'a65wht': '65 years and older of non-Hispanic whites',
#  'ageblk': 'Black population with known age distribution',
#  'a15blk': '0-15 years old of Black race',
#  'a65blk': '65 years and older of Black race',
#  'agehsp': 'Hispanic population with known age distribution',
#  'a15hsp': '0-15 years old, persons of Hispanic origins',
#  'a65hsp': '65 years and older, persons of Hispanic origins',
#  'agentv': 'Native American population with known age distribution',
#  'a15ntv': '0-15 years old of Native American race',
#  'a65ntv': '65 years and older of Native American race',
#  'ageasn': 'Asian and Pacific Islander population with known age distribution',
#  'a15asn': '0-15 years old of Asians and Pacific Islanders',
#  'a65asn': '65 years and older of Asians and Pacific Islanders',
#  'fb': 'Foreign-born',
#  'n10imm': 'Recent immigrants (within the past 10 years)',
#  'nat': 'Naturalized foreign-born',
#  'ag5up': 'Persons 5 years and over',
#  'olang': 'Persons who speak language other than English at home',
#  'lep': 'Persons who speak English not well',
#  'ag25up': 'Population 25 years and over',
#  'hs': 'Persons with high school degree or less',
#  'col': 'Persons with at least a four-year college degree',
#  'clf': 'Civilian labor force 16 years and over',
#  'unemp': 'Unemployed',
#  'dflabf': 'Females 16 years and over, except in armed forces',
#  'flabf': 'Females in labor force',
#  'empclf': 'Employed persons 16 years and over',
#  'prof': 'Professional employees (by occupations)',
#  'manuf': 'Manufacturing employees (by industries)',
#  'semp': 'Self-employed',
#  'ag18cv': 'Civilian population 18 years and over',
#  'vet': 'Veterans',
#  'cni18u': 'Civilian non-institutionalized persons 16-64 years old',
#  'dis': 'Disabled',
#  'hinc': 'Median household income',
#  'hh': 'Total households in sample-based data',
#  'hincw': 'Median household income for whites',
#  'hhw': 'Total white households in sample-based data',
#  'hincb': 'Median household income for Blacks',
#  'hhb': 'Total Black households in sample-based data',
#  'hinch': 'Median household income for Hispanics',
#  'hhh': 'Total Hispanic households in sample-based data',
#  'hincn': 'Median household income for Native Americans',
#  'hhn': 'Total Native American households in sample-based data',
#  'hinca': 'Median household income for Asians and Pacific Islanders',
#  'hha': 'Total Asian/Pacific Islander households in sample-based data',
#  'incpc': 'Per capita income',
#  'dpov': 'Persons for whom poverty status is determined',
#  'npov': 'Persons in poverty',
#  'n65pov': 'Persons 65 years and older in poverty',
#  'dfmpov': 'Families for whom poverty status is determined',
#  'nfmpov': 'Families with children in poverty',
#  'dwpov': 'White persons for whom poverty status is determined',
#  'nwpov': 'Whites in poverty',
#  'dbpov': 'Black persons for whom poverty status is determined',
#  'nbpov': 'Blacks in poverty',
#  'dhpov': 'Hispanics for whom poverty status is determined',
#  'nhpov': 'Hispanics in poverty',
#  'dnapov': 'Native Americans for whom poverty status is determined',
#  'nnapov': 'Native Americans in poverty',
#  'dapov': 'Asians and Pacific Islanders for whom poverty status is determined',
#  'napov': 'Asians and Pacific Islanders in poverty',
#  'hu': 'Housing units',
#  'vac': 'Vacant housing units',
#  'ohu': 'Occupied housing units',
#  'own': 'Owner-occupied housing units',
#  'rent': 'Renter-occupied housing units',
#  'dmulti': 'Total housing units',
#  'multi': 'Housing units in multi-unit structures',
#  'mhmval': 'Median home value',
#  'mrent': 'Median monthly contract rent',
#  'h30old': 'Structures built more than 30 years ago',
#  'h10yrs': 'Household heads moved into unit less than 10 years ago',
#  'a18und': 'Persons age 17 years and under',
#  'a60up': 'Persons age 60 years and over',
#  'a75up': 'Persons age 75 years and over',
#  'ag15up': 'Population 15 years and over',
#  'mar': 'Currently married (excluding separated)',
#  'wds': 'Widowed, divorced, and separated',
#  'family': 'Total families',
#  'fhh': 'Female-headed families with children'}

# %%
var_dict_nonan = {key: var_dict[key] if pd.notna(var_dict[key]) else key for key in var_dict}

# %%
var_dict_nonan
# Out:
# {'Name': 'Description',
#  'tractid': 'Tract GEOID',
#  'tract': 'Tract name',
#  'state': 'state',
#  'county': 'county',
#  'placefp': 'Place FIPS code',
#  'placename': 'placename',
#  'cbsafp': 'CBSA FIPS code',
#  'cbsaname': 'cbsaname',
#  'cbsatype': 'Metropolitan (MSA) or micropolitan (µsa)',
#  'countytype': 'Central or Outlying',
#  'metdivfp': 'Metropolitan division FIPS code',
#  'metdivname': 'metdivname',
#  'Census Variables': 'Census Variables',
#  'micbsa': 'CBSA median income (2022$)',
#  'micity': 'Principal city median income (2022$)',
#  'pop': 'Total population',
#  'nhwht': 'Persons of white race, not Hispanic origin',
#  'nhblk': 'Persons of black race, not Hispanic origin',
#  'hisp': 'Persons of Hispanic origin',
#  'ntv': 'Persons of Native American race',
#  'asian': 'Persons of Asian race (and Pacific Islander)',
#  'agewht': 'White population with known age distribution',
#  'a15wht': '0-15 years old of white race',
#  'a65wht': '65 years and older of non-Hispanic whites',
#  'ageblk': 'Black population with known age distribution',
#  'a15blk': '0-15 years old of Black race',
#  'a65blk': '65 years and older of Black race',
#  'agehsp': 'Hispanic population with known age distribution',
#  'a15hsp': '0-15 years old, persons of Hispanic origins',
#  'a65hsp': '65 years and older, persons of Hispanic origins',
#  'agentv': 'Native American population with known age distribution',
#  'a15ntv': '0-15 years old of Native American race',
#  'a65ntv': '65 years and older of Native American race',
#  'ageasn': 'Asian and Pacific Islander population with known age distribution',
#  'a15asn': '0-15 years old of Asians and Pacific Islanders',
#  'a65asn': '65 years and older of Asians and Pacific Islanders',
#  'fb': 'Foreign-born',
#  'n10imm': 'Recent immigrants (within the past 10 years)',
#  'nat': 'Naturalized foreign-born',
#  'ag5up': 'Persons 5 years and over',
#  'olang': 'Persons who speak language other than English at home',
#  'lep': 'Persons who speak English not well',
#  'ag25up': 'Population 25 years and over',
#  'hs': 'Persons with high school degree or less',
#  'col': 'Persons with at least a four-year college degree',
#  'clf': 'Civilian labor force 16 years and over',
#  'unemp': 'Unemployed',
#  'dflabf': 'Females 16 years and over, except in armed forces',
#  'flabf': 'Females in labor force',
#  'empclf': 'Employed persons 16 years and over',
#  'prof': 'Professional employees (by occupations)',
#  'manuf': 'Manufacturing employees (by industries)',
#  'semp': 'Self-employed',
#  'ag18cv': 'Civilian population 18 years and over',
#  'vet': 'Veterans',
#  'cni18u': 'Civilian non-institutionalized persons 16-64 years old',
#  'dis': 'Disabled',
#  'hinc': 'Median household income',
#  'hh': 'Total households in sample-based data',
#  'hincw': 'Median household income for whites',
#  'hhw': 'Total white households in sample-based data',
#  'hincb': 'Median household income for Blacks',
#  'hhb': 'Total Black households in sample-based data',
#  'hinch': 'Median household income for Hispanics',
#  'hhh': 'Total Hispanic households in sample-based data',
#  'hincn': 'Median household income for Native Americans',
#  'hhn': 'Total Native American households in sample-based data',
#  'hinca': 'Median household income for Asians and Pacific Islanders',
#  'hha': 'Total Asian/Pacific Islander households in sample-based data',
#  'incpc': 'Per capita income',
#  'dpov': 'Persons for whom poverty status is determined',
#  'npov': 'Persons in poverty',
#  'n65pov': 'Persons 65 years and older in poverty',
#  'dfmpov': 'Families for whom poverty status is determined',
#  'nfmpov': 'Families with children in poverty',
#  'dwpov': 'White persons for whom poverty status is determined',
#  'nwpov': 'Whites in poverty',
#  'dbpov': 'Black persons for whom poverty status is determined',
#  'nbpov': 'Blacks in poverty',
#  'dhpov': 'Hispanics for whom poverty status is determined',
#  'nhpov': 'Hispanics in poverty',
#  'dnapov': 'Native Americans for whom poverty status is determined',
#  'nnapov': 'Native Americans in poverty',
#  'dapov': 'Asians and Pacific Islanders for whom poverty status is determined',
#  'napov': 'Asians and Pacific Islanders in poverty',
#  'hu': 'Housing units',
#  'vac': 'Vacant housing units',
#  'ohu': 'Occupied housing units',
#  'own': 'Owner-occupied housing units',
#  'rent': 'Renter-occupied housing units',
#  'dmulti': 'Total housing units',
#  'multi': 'Housing units in multi-unit structures',
#  'mhmval': 'Median home value',
#  'mrent': 'Median monthly contract rent',
#  'h30old': 'Structures built more than 30 years ago',
#  'h10yrs': 'Household heads moved into unit less than 10 years ago',
#  'a18und': 'Persons age 17 years and under',
#  'a60up': 'Persons age 60 years and over',
#  'a75up': 'Persons age 75 years and over',
#  'ag15up': 'Population 15 years and over',
#  'mar': 'Currently married (excluding separated)',
#  'wds': 'Widowed, divorced, and separated',
#  'family': 'Total families',
#  'fhh': 'Female-headed families with children'}

# %%
for k in middle_neighborhoods.keys():
    middle_neighborhoods[k].columns = middle_neighborhoods[k].iloc[0]
    middle_neighborhoods[k].drop(0, inplace=True)
    middle_neighborhoods[k].rename(columns=var_dict_nonan, inplace=True)
    middle_neighborhoods[k]['Year'] = 1900 + int(k[-2:]) if int(k[-2:]) >= 70 else 2000 + int(k[-2:])

# %%
middle_neighborhoods
# Out:
# {'Data70': 0    Tract GEOID         Tract name state            county Place FIPS code  \
#  1    42003010300   Census Tract 103    PA  Allegheny County           61000
#  2    42003020100   Census Tract 201    PA  Allegheny County           61000
#  3    42003020300   Census Tract 203    PA  Allegheny County           61000
#  4    42003030500   Census Tract 305    PA  Allegheny County           61000
#  5    42003040200   Census Tract 402    PA  Allegheny County           61000
#  ..           ...                ...   ...               ...             ...
#  395  42003980900  Census Tract 9809    PA  Allegheny County           61000
#  396  42003981000  Census Tract 9810    PA  Allegheny County           61000
#  397  42003981100  Census Tract 9811    PA  Allegheny County           61000
#  398  42003981800  Census Tract 9818    PA  Allegheny County           61000
#  399  42003982200  Census Tract 9822    PA  Allegheny County           61000
#
#  0          placename CBSA FIPS code        cbsaname  \
#  1    Pittsburgh city          38300  Pittsburgh, PA
#  2    Pittsburgh city          38300  Pittsburgh, PA
#  3    Pittsburgh city          38300  Pittsburgh, PA
#  4    Pittsburgh city          38300  Pittsburgh, PA
#  5    Pittsburgh city          38300  Pittsburgh, PA
#  ..               ...            ...             ...
#  395  Pittsburgh city          38300  Pittsburgh, PA
#  396  Pittsburgh city          38300  Pittsburgh, PA
#  397  Pittsburgh city          38300  Pittsburgh, PA
#  398  Pittsburgh city          38300  Pittsburgh, PA
#  399  Pittsburgh city          38300  Pittsburgh, PA
#
#  0   Metropolitan (MSA) or micropolitan (µsa) Central or Outlying  ... phhnami  \
#  1              Metropolitan Statistical Area             Central  ...     NaN
#  2              Metropolitan Statistical Area             Central  ...     NaN
#  3              Metropolitan Statistical Area             Central  ...     NaN
#  4              Metropolitan Statistical Area             Central  ...     NaN
#  5              Metropolitan Statistical Area             Central  ...     NaN
#  ..                                       ...                 ...  ...     ...
#  395            Metropolitan Statistical Area             Central  ...     NaN
#  396            Metropolitan Statistical Area             Central  ...     NaN
#  397            Metropolitan Statistical Area             Central  ...     NaN
#  398            Metropolitan Statistical Area             Central  ...     NaN
#  399            Metropolitan Statistical Area             Central  ...     NaN
#
#  0   phhncmi phha phhaami phhacmi                     midami  \
#  1       NaN  NaN     NaN     NaN         Tract MI < 80% AMI
#  2       NaN  NaN     NaN     NaN         Tract MI < 80% AMI
#  3       NaN  NaN     NaN     NaN         Tract MI < 80% AMI
#  4       NaN  NaN     NaN     NaN         Tract MI < 80% AMI
#  5       NaN  NaN     NaN     NaN         Tract MI < 80% AMI
#  ..      ...  ...     ...     ...                        ...
#  395     NaN  NaN     NaN     NaN  Middle Neighborhood (AMI)
#  396     NaN  NaN     NaN     NaN  Middle Neighborhood (AMI)
#  397     NaN  NaN     NaN     NaN  Middle Neighborhood (AMI)
#  398     NaN  NaN     NaN     NaN  Middle Neighborhood (AMI)
#  399     NaN  NaN     NaN     NaN         Tract MI < 80% AMI
#
#  0                       midcmi           midmajami             midmajcmi  Year
#  1           Tract MI < 80% CMI  Tract MI < 80% AMI    Tract MI < 80% CMI  1970
#  2           Tract MI < 80% CMI  Tract MI < 80% AMI    Tract MI < 80% CMI  1970
#  3           Tract MI < 80% CMI  Tract MI < 80% AMI    Tract MI < 80% CMI  1970
#  4           Tract MI < 80% CMI  Tract MI < 80% AMI    Tract MI < 80% CMI  1970
#  5           Tract MI < 80% CMI  Tract MI < 80% AMI    Tract MI < 80% CMI  1970
#  ..                         ...                 ...                   ...   ...
#  395  Middle Neighborhood (CMI)        White Middle          White Middle  1970
#  396  Middle Neighborhood (CMI)        White Middle          White Middle  1970
#  397       Tract MI >= 120% CMI        White Middle  Tract MI >= 120% CMI  1970
#  398  Middle Neighborhood (CMI)        White Middle          White Middle  1970
#  399         Tract MI < 80% CMI  Tract MI < 80% AMI    Tract MI < 80% CMI  1970
#
#  [399 rows x 180 columns],
#  'Data80': 0    Tract GEOID         Tract name state            county Place FIPS code  \
#  1    42003010300   Census Tract 103    PA  Allegheny County           61000
#  2    42003020100   Census Tract 201    PA  Allegheny County           61000
#  3    42003020300   Census Tract 203    PA  Allegheny County           61000
#  4    42003030500   Census Tract 305    PA  Allegheny County           61000
#  5    42003040200   Census Tract 402    PA  Allegheny County           61000
#  ..           ...                ...   ...               ...             ...
#  395  42003980900  Census Tract 9809    PA  Allegheny County           61000
#  396  42003981000  Census Tract 9810    PA  Allegheny County           61000
#  397  42003981100  Census Tract 9811    PA  Allegheny County           61000
#  398  42003981800  Census Tract 9818    PA  Allegheny County           61000
#  399  42003982200  Census Tract 9822    PA  Allegheny County           61000
#
#  0          placename CBSA FIPS code        cbsaname  \
#  1    Pittsburgh city          38300  Pittsburgh, PA
#  2    Pittsburgh city          38300  Pittsburgh, PA
#  3    Pittsburgh city          38300  Pittsburgh, PA
#  4    Pittsburgh city          38300  Pittsburgh, PA
#  5    Pittsburgh city          38300  Pittsburgh, PA
#  ..               ...            ...             ...
#  395  Pittsburgh city          38300  Pittsburgh, PA
#  396  Pittsburgh city          38300  Pittsburgh, PA
#  397  Pittsburgh city          38300  Pittsburgh, PA
#  398  Pittsburgh city          38300  Pittsburgh, PA
#  399  Pittsburgh city          38300  Pittsburgh, PA
#
#  0   Metropolitan (MSA) or micropolitan (µsa) Central or Outlying  ... phhnami  \
#  1              Metropolitan Statistical Area             Central  ...     NaN
#  2              Metropolitan Statistical Area             Central  ...     NaN
#  3              Metropolitan Statistical Area             Central  ...     NaN
#  4              Metropolitan Statistical Area             Central  ...     NaN
#  5              Metropolitan Statistical Area             Central  ...     NaN
#  ..                                       ...                 ...  ...     ...
#  395            Metropolitan Statistical Area             Central  ...     NaN
#  396            Metropolitan Statistical Area             Central  ...     NaN
#  397            Metropolitan Statistical Area             Central  ...     NaN
#  398            Metropolitan Statistical Area             Central  ...     NaN
#  399            Metropolitan Statistical Area             Central  ...     NaN
#
#  0   phhncmi      phha   phhaami   phhacmi                     midami  \
#  1       NaN  0.000148  1.192012  1.606389         Tract MI < 80% AMI
#  2       NaN         0       NaN       NaN         Tract MI < 80% AMI
#  3       NaN         0       NaN       NaN         Tract MI < 80% AMI
#  4       NaN         0       NaN       NaN         Tract MI < 80% AMI
#  5       NaN  0.005356       NaN       NaN         Tract MI < 80% AMI
#  ..      ...       ...       ...       ...                        ...
#  395     NaN         0       NaN       NaN         Tract MI < 80% AMI
#  396     NaN         0       NaN       NaN         Tract MI < 80% AMI
#  397     NaN         0       NaN       NaN  Middle Neighborhood (AMI)
#  398     NaN       0.0       NaN       NaN  Middle Neighborhood (AMI)
#  399     NaN  0.008643       NaN       NaN         Tract MI < 80% AMI
#
#  0                       midcmi           midmajami             midmajcmi  Year
#  1           Tract MI < 80% CMI  Tract MI < 80% AMI    Tract MI < 80% CMI  1980
#  2    Middle Neighborhood (CMI)  Tract MI < 80% AMI          White Middle  1980
#  3           Tract MI < 80% CMI  Tract MI < 80% AMI    Tract MI < 80% CMI  1980
#  4           Tract MI < 80% CMI  Tract MI < 80% AMI    Tract MI < 80% CMI  1980
#  5           Tract MI < 80% CMI  Tract MI < 80% AMI    Tract MI < 80% CMI  1980
#  ..                         ...                 ...                   ...   ...
#  395  Middle Neighborhood (CMI)  Tract MI < 80% AMI          White Middle  1980
#  396  Middle Neighborhood (CMI)  Tract MI < 80% AMI          White Middle  1980
#  397       Tract MI >= 120% CMI        White Middle  Tract MI >= 120% CMI  1980
#  398  Middle Neighborhood (CMI)        Black Middle          Black Middle  1980
#  399  Middle Neighborhood (CMI)  Tract MI < 80% AMI          White Middle  1980
#
#  [399 rows x 180 columns],
#  'Data90': 0    Tract GEOID         Tract name state            county Place FIPS code  \
#  1    42003010300   Census Tract 103    PA  Allegheny County           61000
#  2    42003020100   Census Tract 201    PA  Allegheny County           61000
#  3    42003020300   Census Tract 203    PA  Allegheny County           61000
#  4    42003030500   Census Tract 305    PA  Allegheny County           61000
#  5    42003040200   Census Tract 402    PA  Allegheny County           61000
#  ..           ...                ...   ...               ...             ...
#  395  42003980900  Census Tract 9809    PA  Allegheny County           61000
#  396  42003981000  Census Tract 9810    PA  Allegheny County           61000
#  397  42003981100  Census Tract 9811    PA  Allegheny County           61000
#  398  42003981800  Census Tract 9818    PA  Allegheny County           61000
#  399  42003982200  Census Tract 9822    PA  Allegheny County           61000
#
#  0          placename CBSA FIPS code        cbsaname  \
#  1    Pittsburgh city          38300  Pittsburgh, PA
#  2    Pittsburgh city          38300  Pittsburgh, PA
#  3    Pittsburgh city          38300  Pittsburgh, PA
#  4    Pittsburgh city          38300  Pittsburgh, PA
#  5    Pittsburgh city          38300  Pittsburgh, PA
#  ..               ...            ...             ...
#  395  Pittsburgh city          38300  Pittsburgh, PA
#  396  Pittsburgh city          38300  Pittsburgh, PA
#  397  Pittsburgh city          38300  Pittsburgh, PA
#  398  Pittsburgh city          38300  Pittsburgh, PA
#  399  Pittsburgh city          38300  Pittsburgh, PA
#
#  0   Metropolitan (MSA) or micropolitan (µsa) Central or Outlying  ... phhnami  \
#  1              Metropolitan Statistical Area             Central  ...     NaN
#  2              Metropolitan Statistical Area             Central  ...     NaN
#  3              Metropolitan Statistical Area             Central  ...     NaN
#  4              Metropolitan Statistical Area             Central  ...     NaN
#  5              Metropolitan Statistical Area             Central  ...     NaN
#  ..                                       ...                 ...  ...     ...
#  395            Metropolitan Statistical Area             Central  ...     NaN
#  396            Metropolitan Statistical Area             Central  ...     NaN
#  397            Metropolitan Statistical Area             Central  ...     NaN
#  398            Metropolitan Statistical Area             Central  ...     NaN
#  399            Metropolitan Statistical Area             Central  ...     NaN
#
#  0   phhncmi      phha   phhaami   phhacmi                midami  \
#  1       NaN  0.001879  0.204741  0.263488    Tract MI < 80% AMI
#  2       NaN  0.015677  0.749064  0.963995    Tract MI < 80% AMI
#  3       NaN         0       NaN       NaN    Tract MI < 80% AMI
#  4       NaN         0       NaN       NaN    Tract MI < 80% AMI
#  5       NaN  0.038872  0.292603   0.37656    Tract MI < 80% AMI
#  ..      ...       ...       ...       ...                   ...
#  395     NaN         0       NaN       NaN    Tract MI < 80% AMI
#  396     NaN  0.004914  0.093633  0.120499    Tract MI < 80% AMI
#  397     NaN  0.007392  1.123595  1.445992  Tract MI >= 120% AMI
#  398     NaN         0       NaN       NaN    Tract MI < 80% AMI
#  399     NaN  0.091919  0.363801  0.468188    Tract MI < 80% AMI
#
#  0                       midcmi             midmajami             midmajcmi  \
#  1           Tract MI < 80% CMI    Tract MI < 80% AMI    Tract MI < 80% CMI
#  2    Middle Neighborhood (CMI)    Tract MI < 80% AMI          White Middle
#  3    Middle Neighborhood (CMI)    Tract MI < 80% AMI          Black Middle
#  4           Tract MI < 80% CMI    Tract MI < 80% AMI    Tract MI < 80% CMI
#  5           Tract MI < 80% CMI    Tract MI < 80% AMI    Tract MI < 80% CMI
#  ..                         ...                   ...                   ...
#  395  Middle Neighborhood (CMI)    Tract MI < 80% AMI          White Middle
#  396         Tract MI < 80% CMI    Tract MI < 80% AMI    Tract MI < 80% CMI
#  397       Tract MI >= 120% CMI  Tract MI >= 120% AMI  Tract MI >= 120% CMI
#  398  Middle Neighborhood (CMI)    Tract MI < 80% AMI          Black Middle
#  399  Middle Neighborhood (CMI)    Tract MI < 80% AMI          White Middle
#
#  0    Year
#  1    1990
#  2    1990
#  3    1990
#  4    1990
#  5    1990
#  ..    ...
#  395  1990
#  396  1990
#  397  1990
#  398  1990
#  399  1990
#
#  [399 rows x 180 columns],
#  'Data00': 0    Tract GEOID         Tract name state            county Place FIPS code  \
#  1    42003010300   Census Tract 103    PA  Allegheny County           61000
#  2    42003020100   Census Tract 201    PA  Allegheny County           61000
#  3    42003020300   Census Tract 203    PA  Allegheny County           61000
#  4    42003030500   Census Tract 305    PA  Allegheny County           61000
#  5    42003040200   Census Tract 402    PA  Allegheny County           61000
#  ..           ...                ...   ...               ...             ...
#  398  42003981000  Census Tract 9810    PA  Allegheny County           61000
#  399  42003981100  Census Tract 9811    PA  Allegheny County           61000
#  400  42003981200  Census Tract 9812    PA  Allegheny County           61000
#  401  42003981800  Census Tract 9818    PA  Allegheny County           61000
#  402  42003982200  Census Tract 9822    PA  Allegheny County           61000
#
#  0          placename CBSA FIPS code        cbsaname  \
#  1    Pittsburgh city          38300  Pittsburgh, PA
#  2    Pittsburgh city          38300  Pittsburgh, PA
#  3    Pittsburgh city          38300  Pittsburgh, PA
#  4    Pittsburgh city          38300  Pittsburgh, PA
#  5    Pittsburgh city          38300  Pittsburgh, PA
#  ..               ...            ...             ...
#  398  Pittsburgh city          38300  Pittsburgh, PA
#  399  Pittsburgh city          38300  Pittsburgh, PA
#  400  Pittsburgh city          38300  Pittsburgh, PA
#  401  Pittsburgh city          38300  Pittsburgh, PA
#  402  Pittsburgh city          38300  Pittsburgh, PA
#
#  0   Metropolitan (MSA) or micropolitan (µsa) Central or Outlying  ... phhnami  \
#  1              Metropolitan Statistical Area             Central  ...     NaN
#  2              Metropolitan Statistical Area             Central  ...     NaN
#  3              Metropolitan Statistical Area             Central  ...     NaN
#  4              Metropolitan Statistical Area             Central  ...     NaN
#  5              Metropolitan Statistical Area             Central  ...     NaN
#  ..                                       ...                 ...  ...     ...
#  398            Metropolitan Statistical Area             Central  ...     NaN
#  399            Metropolitan Statistical Area             Central  ...     NaN
#  400            Metropolitan Statistical Area             Central  ...     NaN
#  401            Metropolitan Statistical Area             Central  ...     NaN
#  402            Metropolitan Statistical Area             Central  ...     NaN
#
#  0   phhncmi      phha   phhaami   phhacmi                     midami  \
#  1       NaN   0.01081  0.796852  1.044343         Tract MI < 80% AMI
#  2       NaN  0.050806   0.25477  0.333897         Tract MI < 80% AMI
#  3       NaN         0       NaN       NaN  Middle Neighborhood (AMI)
#  4       NaN         0       NaN       NaN         Tract MI < 80% AMI
#  5       NaN  0.015393  1.467958  1.923884         Tract MI < 80% AMI
#  ..      ...       ...       ...       ...                        ...
#  398     NaN         0       NaN       NaN         Tract MI < 80% AMI
#  399     NaN  0.031778  1.408647  1.846151       Tract MI >= 120% AMI
#  400     NaN       NaN       NaN       NaN                        NaN
#  401     NaN  0.000058  0.518975  0.680161         Tract MI < 80% AMI
#  402     NaN  0.128375   0.20759  0.272064  Middle Neighborhood (AMI)
#
#  0                       midcmi             midmajami             midmajcmi  \
#  1           Tract MI < 80% CMI    Tract MI < 80% AMI    Tract MI < 80% CMI
#  2           Tract MI < 80% CMI    Tract MI < 80% AMI    Tract MI < 80% CMI
#  3         Tract MI >= 120% CMI          Black Middle  Tract MI >= 120% CMI
#  4           Tract MI < 80% CMI    Tract MI < 80% AMI    Tract MI < 80% CMI
#  5    Middle Neighborhood (CMI)    Tract MI < 80% AMI          Black Middle
#  ..                         ...                   ...                   ...
#  398         Tract MI < 80% CMI    Tract MI < 80% AMI    Tract MI < 80% CMI
#  399       Tract MI >= 120% CMI  Tract MI >= 120% AMI  Tract MI >= 120% CMI
#  400                        NaN                   NaN                   NaN
#  401         Tract MI < 80% CMI    Tract MI < 80% AMI    Tract MI < 80% CMI
#  402       Tract MI >= 120% CMI          White Middle  Tract MI >= 120% CMI
#
#  0    Year
#  1    2000
#  2    2000
#  3    2000
#  4    2000
#  5    2000
#  ..    ...
#  398  2000
#  399  2000
#  400  2000
#  401  2000
#  402  2000
#
#  [402 rows x 180 columns],
#  'Data12': 0    Tract GEOID         Tract name state            county Place FIPS code  \
#  1    42003010300   Census Tract 103    PA  Allegheny County           61000
#  2    42003020100   Census Tract 201    PA  Allegheny County           61000
#  3    42003020300   Census Tract 203    PA  Allegheny County           61000
#  4    42003030500   Census Tract 305    PA  Allegheny County           61000
#  5    42003040200   Census Tract 402    PA  Allegheny County           61000
#  ..           ...                ...   ...               ...             ...
#  393  42003980700  Census Tract 9807    PA  Allegheny County           61000
#  394  42003980900  Census Tract 9809    PA  Allegheny County           61000
#  395  42003981000  Census Tract 9810    PA  Allegheny County           61000
#  396  42003981800  Census Tract 9818    PA  Allegheny County           61000
#  397  42003982200  Census Tract 9822    PA  Allegheny County           61000
#
#  0          placename CBSA FIPS code        cbsaname  \
#  1    Pittsburgh city          38300  Pittsburgh, PA
#  2    Pittsburgh city          38300  Pittsburgh, PA
#  3    Pittsburgh city          38300  Pittsburgh, PA
#  4    Pittsburgh city          38300  Pittsburgh, PA
#  5    Pittsburgh city          38300  Pittsburgh, PA
#  ..               ...            ...             ...
#  393  Pittsburgh city          38300  Pittsburgh, PA
#  394  Pittsburgh city          38300  Pittsburgh, PA
#  395  Pittsburgh city          38300  Pittsburgh, PA
#  396  Pittsburgh city          38300  Pittsburgh, PA
#  397  Pittsburgh city          38300  Pittsburgh, PA
#
#  0   Metropolitan (MSA) or micropolitan (µsa) Central or Outlying  ... phhnami  \
#  1              Metropolitan Statistical Area             Central  ...     NaN
#  2              Metropolitan Statistical Area             Central  ...     NaN
#  3              Metropolitan Statistical Area             Central  ...     NaN
#  4              Metropolitan Statistical Area             Central  ...     NaN
#  5              Metropolitan Statistical Area             Central  ...     NaN
#  ..                                       ...                 ...  ...     ...
#  393            Metropolitan Statistical Area             Central  ...     NaN
#  394            Metropolitan Statistical Area             Central  ...     NaN
#  395            Metropolitan Statistical Area             Central  ...     NaN
#  396            Metropolitan Statistical Area             Central  ...     NaN
#  397            Metropolitan Statistical Area             Central  ...     NaN
#
#  0   phhncmi      phha   phhaami   phhacmi                     midami  \
#  1       NaN         0       NaN       NaN         Tract MI < 80% AMI
#  2       NaN  0.106529  1.759376  2.321623  Middle Neighborhood (AMI)
#  3       NaN  0.135638  1.570842  2.072839       Tract MI >= 120% AMI
#  4       NaN         0       NaN       NaN         Tract MI < 80% AMI
#  5       NaN  0.044207  0.500259  0.660128         Tract MI < 80% AMI
#  ..      ...       ...       ...       ...                        ...
#  393     NaN         0       NaN       NaN       Tract MI >= 120% AMI
#  394     NaN       NaN       NaN       NaN                        NaN
#  395     NaN         0       NaN       NaN                        NaN
#  396     NaN         0       NaN       NaN         Tract MI < 80% AMI
#  397     NaN         0       NaN       NaN         Tract MI < 80% AMI
#
#  0                       midcmi             midmajami              midmajcmi  \
#  1           Tract MI < 80% CMI    Tract MI < 80% AMI     Tract MI < 80% CMI
#  2         Tract MI >= 120% CMI          White Middle   Tract MI >= 120% CMI
#  3         Tract MI >= 120% CMI  Tract MI >= 120% AMI   Tract MI >= 120% CMI
#  4           Tract MI < 80% CMI    Tract MI < 80% AMI     Tract MI < 80% CMI
#  5           Tract MI < 80% CMI    Tract MI < 80% AMI     Tract MI < 80% CMI
#  ..                         ...                   ...                    ...
#  393       Tract MI >= 120% CMI  Tract MI >= 120% AMI   Tract MI >= 120% CMI
#  394                        NaN                   NaN                    NaN
#  395                        NaN                   NaN                    NaN
#  396  Middle Neighborhood (CMI)    Tract MI < 80% AMI  Mixed-Minority Middle
#  397         Tract MI < 80% CMI    Tract MI < 80% AMI     Tract MI < 80% CMI
#
#  0    Year
#  1    2012
#  2    2012
#  3    2012
#  4    2012
#  5    2012
#  ..    ...
#  393  2012
#  394  2012
#  395  2012
#  396  2012
#  397  2012
#
#  [397 rows x 180 columns],
#  'Data22': 0    Tract GEOID           Tract name state            county Place FIPS code  \
#  1    42003010301  Census Tract 103.01    PA  Allegheny County           61000
#  2    42003010302  Census Tract 103.02    PA  Allegheny County           61000
#  3    42003020100     Census Tract 201    PA  Allegheny County           61000
#  4    42003020300     Census Tract 203    PA  Allegheny County           61000
#  5    42003030500     Census Tract 305    PA  Allegheny County           61000
#  ..           ...                  ...   ...               ...             ...
#  382  42003980600    Census Tract 9806    PA  Allegheny County           61000
#  383  42003980700    Census Tract 9807    PA  Allegheny County           61000
#  384  42003980900    Census Tract 9809    PA  Allegheny County           61000
#  385  42003981800    Census Tract 9818    PA  Allegheny County           61000
#  386  42003982200    Census Tract 9822    PA  Allegheny County           61000
#
#  0          placename CBSA FIPS code        cbsaname  \
#  1    Pittsburgh city          38300  Pittsburgh, PA
#  2    Pittsburgh city          38300  Pittsburgh, PA
#  3    Pittsburgh city          38300  Pittsburgh, PA
#  4    Pittsburgh city          38300  Pittsburgh, PA
#  5    Pittsburgh city          38300  Pittsburgh, PA
#  ..               ...            ...             ...
#  382  Pittsburgh city          38300  Pittsburgh, PA
#  383  Pittsburgh city          38300  Pittsburgh, PA
#  384  Pittsburgh city          38300  Pittsburgh, PA
#  385  Pittsburgh city          38300  Pittsburgh, PA
#  386  Pittsburgh city          38300  Pittsburgh, PA
#
#  0   Metropolitan (MSA) or micropolitan (µsa) Central or Outlying  ... phhnami  \
#  1              Metropolitan Statistical Area             Central  ...     NaN
#  2              Metropolitan Statistical Area             Central  ...     NaN
#  3              Metropolitan Statistical Area             Central  ...     NaN
#  4              Metropolitan Statistical Area             Central  ...     NaN
#  5              Metropolitan Statistical Area             Central  ...     NaN
#  ..                                       ...                 ...  ...     ...
#  382            Metropolitan Statistical Area             Central  ...     NaN
#  383            Metropolitan Statistical Area             Central  ...     NaN
#  384            Metropolitan Statistical Area             Central  ...     NaN
#  385            Metropolitan Statistical Area             Central  ...     NaN
#  386            Metropolitan Statistical Area             Central  ...     NaN
#
#  0   phhncmi      phha   phhaami   phhacmi                     midami  \
#  1       NaN       NaN       NaN       NaN                        NaN
#  2       NaN  0.018634       NaN       NaN         Tract MI < 80% AMI
#  3       NaN  0.160629  1.643912  1.946982       Tract MI >= 120% AMI
#  4       NaN  0.134958  1.358697  1.609185       Tract MI >= 120% AMI
#  5       NaN  0.095751  0.663117  0.785369         Tract MI < 80% AMI
#  ..      ...       ...       ...       ...                        ...
#  382     NaN         0       NaN       NaN                        NaN
#  383     NaN         0       NaN       NaN  Middle Neighborhood (AMI)
#  384     NaN       NaN       NaN       NaN                        NaN
#  385     NaN       NaN       NaN       NaN                        NaN
#  386     NaN         0       NaN       NaN                        NaN
#
#  0                       midcmi             midmajami             midmajcmi  \
#  1                          NaN                   NaN                   NaN
#  2    Middle Neighborhood (CMI)    Tract MI < 80% AMI          White Middle
#  3         Tract MI >= 120% CMI  Tract MI >= 120% AMI  Tract MI >= 120% CMI
#  4         Tract MI >= 120% CMI  Tract MI >= 120% AMI  Tract MI >= 120% CMI
#  5           Tract MI < 80% CMI    Tract MI < 80% AMI    Tract MI < 80% CMI
#  ..                         ...                   ...                   ...
#  382                        NaN                   NaN                   NaN
#  383       Tract MI >= 120% CMI          White Middle  Tract MI >= 120% CMI
#  384                        NaN                   NaN                   NaN
#  385                        NaN                   NaN                   NaN
#  386                        NaN                   NaN                   NaN
#
#  0    Year
#  1    2022
#  2    2022
#  3    2022
#  4    2022
#  5    2022
#  ..    ...
#  382  2022
#  383  2022
#  384  2022
#  385  2022
#  386  2022
#
#  [386 rows x 180 columns]}

# %%
all_data = pd.concat(middle_neighborhoods.values(), names=['year', 'row'])

# %%
all_data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2382 entries, 1 to 386
# Data columns (total 191 columns):
#  #    Column                                                              Dtype
# ---   ------                                                              -----
#  0    Tract GEOID                                                         object
#  1    Tract name                                                          object
#  2    state                                                               object
#  3    county                                                              object
#  4    Place FIPS code                                                     object
#  5    placename                                                           object
#  6    CBSA FIPS code                                                      object
#  7    cbsaname                                                            object
#  8    Metropolitan (MSA) or micropolitan (µsa)                            object
#  9    Central or Outlying                                                 object
#  10   Metropolitan division FIPS code                                     object
#  11   metdivname                                                          object
#  12   CBSA median income (2022$)                                          object
#  13   Principal city median income (2022$)                                object
#  14   Total population                                                    object
#  15   Persons of white race, not Hispanic origin                          object
#  16   Persons of black race, not Hispanic origin                          object
#  17   Persons of Hispanic origin                                          object
#  18   Persons of Native American race                                     object
#  19   Persons of Asian race (and Pacific Islander)                        object
#  20   White population with known age distribution                        object
#  21   0-15 years old of white race                                        object
#  22   a60wht                                                              object
#  23   Black population with known age distribution                        object
#  24   0-15 years old of Black race                                        object
#  25   a60blk                                                              object
#  26   Hispanic population with known age distribution                     object
#  27   0-15 years old, persons of Hispanic origins                         object
#  28   a60hsp                                                              object
#  29   Native American population with known age distribution              object
#  30   0-15 years old of Native American race                              object
#  31   a60ntv                                                              object
#  32   Asian and Pacific Islander population with known age distribution   object
#  33   0-15 years old of Asians and Pacific Islanders                      object
#  34   a60asn                                                              object
#  35   Foreign-born                                                        object
#  36   Recent immigrants (within the past 10 years)                        object
#  37   Naturalized foreign-born                                            object
#  38   Persons 5 years and over                                            object
#  39   Persons who speak language other than English at home               object
#  40   Persons who speak English not well                                  object
#  41   Population 25 years and over                                        object
#  42   Persons with high school degree or less                             object
#  43   Persons with at least a four-year college degree                    object
#  44   Civilian labor force 16 years and over                              object
#  45   Unemployed                                                          object
#  46   Females 16 years and over, except in armed forces                   object
#  47   Females in labor force                                              object
#  48   Employed persons 16 years and over                                  object
#  49   Professional employees (by occupations)                             object
#  50   Manufacturing employees (by industries)                             object
#  51   Self-employed                                                       object
#  52   Civilian population 18 years and over                               object
#  53   Veterans                                                            object
#  54   cni16u                                                              object
#  55   Disabled                                                            object
#  56   Median household income                                             object
#  57   Total households in sample-based data                               object
#  58   Median household income for whites                                  object
#  59   Total white households in sample-based data                         object
#  60   Median household income for Blacks                                  object
#  61   Total Black households in sample-based data                         object
#  62   Median household income for Hispanics                               object
#  63   Total Hispanic households in sample-based data                      object
#  64   Median household income for Native Americans                        object
#  65   Total Native American households in sample-based data               object
#  66   Median household income for Asians and Pacific Islanders            object
#  67   Total Asian/Pacific Islander households in sample-based data        object
#  68   Per capita income                                                   object
#  69   Persons for whom poverty status is determined                       object
#  70   Persons in poverty                                                  object
#  71   Persons 65 years and older in poverty                               object
#  72   Families for whom poverty status is determined                      object
#  73   Families with children in poverty                                   object
#  74   White persons for whom poverty status is determined                 object
#  75   Whites in poverty                                                   object
#  76   Black persons for whom poverty status is determined                 object
#  77   Blacks in poverty                                                   object
#  78   Hispanics for whom poverty status is determined                     object
#  79   Hispanics in poverty                                                object
#  80   Native Americans for whom poverty status is determined              object
#  81   Native Americans in poverty                                         object
#  82   Asians and Pacific Islanders for whom poverty status is determined  object
#  83   Asians and Pacific Islanders in poverty                             object
#  84   Housing units                                                       object
#  85   Vacant housing units                                                object
#  86   Occupied housing units                                              object
#  87   Owner-occupied housing units                                        object
#  88   Renter-occupied housing units                                       object
#  89   Total housing units                                                 object
#  90   Housing units in multi-unit structures                              object
#  91   Median home value                                                   object
#  92   Median monthly contract rent                                        object
#  93   Structures built more than 30 years ago                             object
#  94   Household heads moved into unit less than 10 years ago              object
#  95   Persons age 17 years and under                                      object
#  96   Persons age 60 years and over                                       object
#  97   Persons age 75 years and over                                       object
#  98   Population 15 years and over                                        object
#  99   Currently married (excluding separated)                             object
#  100  Widowed, divorced, and separated                                    object
#  101  Total families                                                      object
#  102  Female-headed families with children                                object
#  103  popsp1                                                              object
#  104  popsf3                                                              object
#  105  popsf4                                                              object
#  106  husp                                                                object
#  107  ohusp                                                               object
#  108  minority                                                            object
#  109  pmin                                                                object
#  110  pnhwht                                                              object
#  111  pnhblk                                                              object
#  112  phisp                                                               object
#  113  pntv                                                                object
#  114  pasian                                                              object
#  115  p15wht                                                              object
#  116  p65wht                                                              object
#  117  p15blk                                                              object
#  118  p65blk                                                              object
#  119  p15hsp                                                              object
#  120  p65hsp                                                              object
#  121  p15ntv                                                              object
#  122  p65ntv                                                              object
#  123  p15asn                                                              object
#  124  p65asn                                                              object
#  125  pfb                                                                 object
#  126  p10imm                                                              object
#  127  pnat                                                                object
#  128  polang                                                              object
#  129  plep                                                                object
#  130  phs                                                                 object
#  131  pcol                                                                object
#  132  punemp                                                              object
#  133  pflabf                                                              object
#  134  pprof                                                               object
#  135  pmanuf                                                              object
#  136  psemp                                                               object
#  137  pvet                                                                object
#  138  pdis                                                                object
#  139  ppov                                                                object
#  140  p65pov                                                              object
#  141  pfmpov                                                              object
#  142  pwpov                                                               object
#  143  pbpov                                                               object
#  144  phpov                                                               object
#  145  pnapov                                                              object
#  146  papov                                                               object
#  147  pvac                                                                object
#  148  pown                                                                object
#  149  pmulti                                                              object
#  150  p30old                                                              object
#  151  p10yrs                                                              object
#  152  p18und                                                              object
#  153  p60up                                                               object
#  154  p75up                                                               object
#  155  pmar                                                                object
#  156  pwds                                                                object
#  157  pfhh                                                                object
#  158  phhami                                                              object
#  159  phhcmi                                                              object
#  160  phhw                                                                object
#  161  phhwami                                                             object
#  162  phhwcmi                                                             object
#  163  phhb                                                                object
#  164  phhbami                                                             object
#  165  phhbcmi                                                             object
#  166  phhh                                                                object
#  167  phhhami                                                             object
#  168  phhhcmi                                                             object
#  169  phhn                                                                object
#  170  phhnami                                                             object
#  171  phhncmi                                                             object
#  172  phha                                                                object
#  173  phhaami                                                             object
#  174  phhacmi                                                             object
#  175  midami                                                              object
#  176  midcmi                                                              object
#  177  midmajami                                                           object
#  178  midmajcmi                                                           object
#  179  Year                                                                int64
#  180  p60wht                                                              object
#  181  p60blk                                                              object
#  182  p60hsp                                                              object
#  183  p60ntv                                                              object
#  184  p60asn                                                              object
#  185  65 years and older of non-Hispanic whites                           object
#  186  65 years and older of Black race                                    object
#  187  65 years and older, persons of Hispanic origins                     object
#  188  65 years and older of Native American race                          object
#  189  65 years and older of Asians and Pacific Islanders                  object
#  190  Civilian non-institutionalized persons 16-64 years old              object
# dtypes: int64(1), object(190)
# memory usage: 3.5+ MB

# %%
for c in all_data.columns:
    print(c)
# Out:
# Tract GEOID
# Tract name
# state
# county
# Place FIPS code
# placename
# CBSA FIPS code
# cbsaname
# Metropolitan (MSA) or micropolitan (µsa)
# Central or Outlying
# Metropolitan division FIPS code
# metdivname
# CBSA median income (2022$)
# Principal city median income (2022$)
# Total population
# Persons of white race, not Hispanic origin
# Persons of black race, not Hispanic origin
# Persons of Hispanic origin
# Persons of Native American race
# Persons of Asian race (and Pacific Islander)
# White population with known age distribution
# 0-15 years old of white race
# a60wht
# Black population with known age distribution
# 0-15 years old of Black race
# a60blk
# Hispanic population with known age distribution
# 0-15 years old, persons of Hispanic origins
# a60hsp
# Native American population with known age distribution
# 0-15 years old of Native American race
# a60ntv
# Asian and Pacific Islander population with known age distribution
# 0-15 years old of Asians and Pacific Islanders
# a60asn
# Foreign-born
# Recent immigrants (within the past 10 years)
# Naturalized foreign-born
# Persons 5 years and over
# Persons who speak language other than English at home
# Persons who speak English not well
# Population 25 years and over
# Persons with high school degree or less
# Persons with at least a four-year college degree
# Civilian labor force 16 years and over
# Unemployed
# Females 16 years and over, except in armed forces
# Females in labor force
# Employed persons 16 years and over
# Professional employees (by occupations)
# Manufacturing employees (by industries)
# Self-employed
# Civilian population 18 years and over
# Veterans
# cni16u
# Disabled
# Median household income
# Total households in sample-based data
# Median household income for whites
# Total white households in sample-based data
# Median household income for Blacks
# Total Black households in sample-based data
# Median household income for Hispanics
# Total Hispanic households in sample-based data
# Median household income for Native Americans
# Total Native American households in sample-based data
# Median household income for Asians and Pacific Islanders
# Total Asian/Pacific Islander households in sample-based data
# Per capita income
# Persons for whom poverty status is determined
# Persons in poverty
# Persons 65 years and older in poverty
# Families for whom poverty status is determined
# Families with children in poverty
# White persons for whom poverty status is determined
# Whites in poverty
# Black persons for whom poverty status is determined
# Blacks in poverty
# Hispanics for whom poverty status is determined
# Hispanics in poverty
# Native Americans for whom poverty status is determined
# Native Americans in poverty
# Asians and Pacific Islanders for whom poverty status is determined
# Asians and Pacific Islanders in poverty
# Housing units
# Vacant housing units
# Occupied housing units
# Owner-occupied housing units
# Renter-occupied housing units
# Total housing units
# Housing units in multi-unit structures
# Median home value
# Median monthly contract rent
# Structures built more than 30 years ago
# Household heads moved into unit less than 10 years ago
# Persons age 17 years and under
# Persons age 60 years and over
# Persons age 75 years and over
# Population 15 years and over
# Currently married (excluding separated)
# Widowed, divorced, and separated
# Total families
# Female-headed families with children
# popsp1
# popsf3
# popsf4
# husp
# ohusp
# minority
# pmin
# pnhwht
# pnhblk
# phisp
# pntv
# pasian
# p15wht
# p65wht
# p15blk
# p65blk
# p15hsp
# p65hsp
# p15ntv
# p65ntv
# p15asn
# p65asn
# pfb
# p10imm
# pnat
# polang
# plep
# phs
# pcol
# punemp
# pflabf
# pprof
# pmanuf
# psemp
# pvet
# pdis
# ppov
# p65pov
# pfmpov
# pwpov
# pbpov
# phpov
# pnapov
# papov
# pvac
# pown
# pmulti
# p30old
# p10yrs
# p18und
# p60up
# p75up
# pmar
# pwds
# pfhh
# phhami
# phhcmi
# phhw
# phhwami
# phhwcmi
# phhb
# phhbami
# phhbcmi
# phhh
# phhhami
# phhhcmi
# phhn
# phhnami
# phhncmi
# phha
# phhaami
# phhacmi
# midami
# midcmi
# midmajami
# midmajcmi
# Year
# p60wht
# p60blk
# p60hsp
# p60ntv
# p60asn
# 65 years and older of non-Hispanic whites
# 65 years and older of Black race
# 65 years and older, persons of Hispanic origins
# 65 years and older of Native American race
# 65 years and older of Asians and Pacific Islanders
# Civilian non-institutionalized persons 16-64 years old

# %%
recent_data = all_data[all_data['Year'] >= 2000]

# %%
recent_data.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1185 entries, 1 to 386
# Data columns (total 191 columns):
#  #    Column                                                              Non-Null Count  Dtype
# ---   ------                                                              --------------  -----
#  0    Tract GEOID                                                         1185 non-null   object
#  1    Tract name                                                          1185 non-null   object
#  2    state                                                               1185 non-null   object
#  3    county                                                              1185 non-null   object
#  4    Place FIPS code                                                     1005 non-null   object
#  5    placename                                                           904 non-null    object
#  6    CBSA FIPS code                                                      1185 non-null   object
#  7    cbsaname                                                            1185 non-null   object
#  8    Metropolitan (MSA) or micropolitan (µsa)                            1185 non-null   object
#  9    Central or Outlying                                                 1185 non-null   object
#  10   Metropolitan division FIPS code                                     0 non-null      object
#  11   metdivname                                                          0 non-null      object
#  12   CBSA median income (2022$)                                          1185 non-null   object
#  13   Principal city median income (2022$)                                1185 non-null   object
#  14   Total population                                                    1185 non-null   object
#  15   Persons of white race, not Hispanic origin                          1185 non-null   object
#  16   Persons of black race, not Hispanic origin                          1185 non-null   object
#  17   Persons of Hispanic origin                                          1185 non-null   object
#  18   Persons of Native American race                                     1185 non-null   object
#  19   Persons of Asian race (and Pacific Islander)                        1185 non-null   object
#  20   White population with known age distribution                        1185 non-null   object
#  21   0-15 years old of white race                                        1185 non-null   object
#  22   a60wht                                                              799 non-null    object
#  23   Black population with known age distribution                        1185 non-null   object
#  24   0-15 years old of Black race                                        1185 non-null   object
#  25   a60blk                                                              799 non-null    object
#  26   Hispanic population with known age distribution                     1185 non-null   object
#  27   0-15 years old, persons of Hispanic origins                         1185 non-null   object
#  28   a60hsp                                                              799 non-null    object
#  29   Native American population with known age distribution              1185 non-null   object
#  30   0-15 years old of Native American race                              1185 non-null   object
#  31   a60ntv                                                              799 non-null    object
#  32   Asian and Pacific Islander population with known age distribution   1185 non-null   object
#  33   0-15 years old of Asians and Pacific Islanders                      1185 non-null   object
#  34   a60asn                                                              799 non-null    object
#  35   Foreign-born                                                        1185 non-null   object
#  36   Recent immigrants (within the past 10 years)                        1185 non-null   object
#  37   Naturalized foreign-born                                            1185 non-null   object
#  38   Persons 5 years and over                                            1185 non-null   object
#  39   Persons who speak language other than English at home               1185 non-null   object
#  40   Persons who speak English not well                                  1185 non-null   object
#  41   Population 25 years and over                                        1185 non-null   object
#  42   Persons with high school degree or less                             1185 non-null   object
#  43   Persons with at least a four-year college degree                    1185 non-null   object
#  44   Civilian labor force 16 years and over                              1185 non-null   object
#  45   Unemployed                                                          1185 non-null   object
#  46   Females 16 years and over, except in armed forces                   1185 non-null   object
#  47   Females in labor force                                              1185 non-null   object
#  48   Employed persons 16 years and over                                  1185 non-null   object
#  49   Professional employees (by occupations)                             1185 non-null   object
#  50   Manufacturing employees (by industries)                             1185 non-null   object
#  51   Self-employed                                                       1185 non-null   object
#  52   Civilian population 18 years and over                               1185 non-null   object
#  53   Veterans                                                            1185 non-null   object
#  54   cni16u                                                              799 non-null    object
#  55   Disabled                                                            1185 non-null   object
#  56   Median household income                                             1174 non-null   object
#  57   Total households in sample-based data                               1185 non-null   object
#  58   Median household income for whites                                  1151 non-null   object
#  59   Total white households in sample-based data                         1185 non-null   object
#  60   Median household income for Blacks                                  864 non-null    object
#  61   Total Black households in sample-based data                         1185 non-null   object
#  62   Median household income for Hispanics                               562 non-null    object
#  63   Total Hispanic households in sample-based data                      1185 non-null   object
#  64   Median household income for Native Americans                        12 non-null     object
#  65   Total Native American households in sample-based data               783 non-null    object
#  66   Median household income for Asians and Pacific Islanders            588 non-null    object
#  67   Total Asian/Pacific Islander households in sample-based data        1185 non-null   object
#  68   Per capita income                                                   1182 non-null   object
#  69   Persons for whom poverty status is determined                       1185 non-null   object
#  70   Persons in poverty                                                  1185 non-null   object
#  71   Persons 65 years and older in poverty                               1185 non-null   object
#  72   Families for whom poverty status is determined                      1185 non-null   object
#  73   Families with children in poverty                                   1185 non-null   object
#  74   White persons for whom poverty status is determined                 1185 non-null   object
#  75   Whites in poverty                                                   1185 non-null   object
#  76   Black persons for whom poverty status is determined                 1185 non-null   object
#  77   Blacks in poverty                                                   1185 non-null   object
#  78   Hispanics for whom poverty status is determined                     1185 non-null   object
#  79   Hispanics in poverty                                                1185 non-null   object
#  80   Native Americans for whom poverty status is determined              1185 non-null   object
#  81   Native Americans in poverty                                         1185 non-null   object
#  82   Asians and Pacific Islanders for whom poverty status is determined  1185 non-null   object
#  83   Asians and Pacific Islanders in poverty                             1185 non-null   object
#  84   Housing units                                                       1185 non-null   object
#  85   Vacant housing units                                                1185 non-null   object
#  86   Occupied housing units                                              1185 non-null   object
#  87   Owner-occupied housing units                                        1185 non-null   object
#  88   Renter-occupied housing units                                       1185 non-null   object
#  89   Total housing units                                                 1185 non-null   object
#  90   Housing units in multi-unit structures                              1185 non-null   object
#  91   Median home value                                                   1164 non-null   object
#  92   Median monthly contract rent                                        1156 non-null   object
#  93   Structures built more than 30 years ago                             1185 non-null   object
#  94   Household heads moved into unit less than 10 years ago              1185 non-null   object
#  95   Persons age 17 years and under                                      1185 non-null   object
#  96   Persons age 60 years and over                                       1185 non-null   object
#  97   Persons age 75 years and over                                       1185 non-null   object
#  98   Population 15 years and over                                        1185 non-null   object
#  99   Currently married (excluding separated)                             1185 non-null   object
#  100  Widowed, divorced, and separated                                    1185 non-null   object
#  101  Total families                                                      1185 non-null   object
#  102  Female-headed families with children                                1185 non-null   object
#  103  popsp1                                                              0 non-null      object
#  104  popsf3                                                              402 non-null    object
#  105  popsf4                                                              0 non-null      object
#  106  husp                                                                402 non-null    object
#  107  ohusp                                                               402 non-null    object
#  108  minority                                                            1185 non-null   object
#  109  pmin                                                                1183 non-null   object
#  110  pnhwht                                                              1183 non-null   object
#  111  pnhblk                                                              1183 non-null   object
#  112  phisp                                                               1183 non-null   object
#  113  pntv                                                                1183 non-null   object
#  114  pasian                                                              1183 non-null   object
#  115  p15wht                                                              1183 non-null   object
#  116  p65wht                                                              1183 non-null   object
#  117  p15blk                                                              1145 non-null   object
#  118  p65blk                                                              1145 non-null   object
#  119  p15hsp                                                              1077 non-null   object
#  120  p65hsp                                                              1077 non-null   object
#  121  p15ntv                                                              589 non-null    object
#  122  p65ntv                                                              589 non-null    object
#  123  p15asn                                                              969 non-null    object
#  124  p65asn                                                              969 non-null    object
#  125  pfb                                                                 1183 non-null   object
#  126  p10imm                                                              1183 non-null   object
#  127  pnat                                                                1183 non-null   object
#  128  polang                                                              1183 non-null   object
#  129  plep                                                                1183 non-null   object
#  130  phs                                                                 1183 non-null   object
#  131  pcol                                                                1183 non-null   object
#  132  punemp                                                              1178 non-null   object
#  133  pflabf                                                              1179 non-null   object
#  134  pprof                                                               1178 non-null   object
#  135  pmanuf                                                              1178 non-null   object
#  136  psemp                                                               1178 non-null   object
#  137  pvet                                                                1183 non-null   object
#  138  pdis                                                                1180 non-null   object
#  139  ppov                                                                1180 non-null   object
#  140  p65pov                                                              1180 non-null   object
#  141  pfmpov                                                              1176 non-null   object
#  142  pwpov                                                               1180 non-null   object
#  143  pbpov                                                               1129 non-null   object
#  144  phpov                                                               1043 non-null   object
#  145  pnapov                                                              409 non-null    object
#  146  papov                                                               928 non-null    object
#  147  pvac                                                                1179 non-null   object
#  148  pown                                                                1179 non-null   object
#  149  pmulti                                                              1179 non-null   object
#  150  p30old                                                              1179 non-null   object
#  151  p10yrs                                                              1179 non-null   object
#  152  p18und                                                              1183 non-null   object
#  153  p60up                                                               1183 non-null   object
#  154  p75up                                                               1183 non-null   object
#  155  pmar                                                                1183 non-null   object
#  156  pwds                                                                1183 non-null   object
#  157  pfhh                                                                1176 non-null   object
#  158  phhami                                                              1174 non-null   object
#  159  phhcmi                                                              1174 non-null   object
#  160  phhw                                                                1179 non-null   object
#  161  phhwami                                                             1151 non-null   object
#  162  phhwcmi                                                             1151 non-null   object
#  163  phhb                                                                1179 non-null   object
#  164  phhbami                                                             864 non-null    object
#  165  phhbcmi                                                             864 non-null    object
#  166  phhh                                                                1179 non-null   object
#  167  phhhami                                                             562 non-null    object
#  168  phhhcmi                                                             562 non-null    object
#  169  phhn                                                                779 non-null    object
#  170  phhnami                                                             12 non-null     object
#  171  phhncmi                                                             12 non-null     object
#  172  phha                                                                1179 non-null   object
#  173  phhaami                                                             588 non-null    object
#  174  phhacmi                                                             588 non-null    object
#  175  midami                                                              1174 non-null   object
#  176  midcmi                                                              1174 non-null   object
#  177  midmajami                                                           1174 non-null   object
#  178  midmajcmi                                                           1174 non-null   object
#  179  Year                                                                1185 non-null   int64
#  180  p60wht                                                              0 non-null      object
#  181  p60blk                                                              0 non-null      object
#  182  p60hsp                                                              0 non-null      object
#  183  p60ntv                                                              0 non-null      object
#  184  p60asn                                                              0 non-null      object
#  185  65 years and older of non-Hispanic whites                           386 non-null    object
#  186  65 years and older of Black race                                    386 non-null    object
#  187  65 years and older, persons of Hispanic origins                     386 non-null    object
#  188  65 years and older of Native American race                          386 non-null    object
#  189  65 years and older of Asians and Pacific Islanders                  386 non-null    object
#  190  Civilian non-institutionalized persons 16-64 years old              386 non-null    object
# dtypes: int64(1), object(190)
# memory usage: 1.7+ MB

# %%
null_cols = [c for c in recent_data.columns if recent_data[c].isna().all()]

# %%
recent_data = recent_data.drop(columns=null_cols)

# %%
recent_00 = recent_data[recent_data['Year'] == 2000]
recent_00.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 402 entries, 1 to 402
# Data columns (total 182 columns):
#  #    Column                                                              Non-Null Count  Dtype
# ---   ------                                                              --------------  -----
#  0    Tract GEOID                                                         402 non-null    object
#  1    Tract name                                                          402 non-null    object
#  2    state                                                               402 non-null    object
#  3    county                                                              402 non-null    object
#  4    Place FIPS code                                                     312 non-null    object
#  5    placename                                                           312 non-null    object
#  6    CBSA FIPS code                                                      402 non-null    object
#  7    cbsaname                                                            402 non-null    object
#  8    Metropolitan (MSA) or micropolitan (µsa)                            402 non-null    object
#  9    Central or Outlying                                                 402 non-null    object
#  10   CBSA median income (2022$)                                          402 non-null    object
#  11   Principal city median income (2022$)                                402 non-null    object
#  12   Total population                                                    402 non-null    object
#  13   Persons of white race, not Hispanic origin                          402 non-null    object
#  14   Persons of black race, not Hispanic origin                          402 non-null    object
#  15   Persons of Hispanic origin                                          402 non-null    object
#  16   Persons of Native American race                                     402 non-null    object
#  17   Persons of Asian race (and Pacific Islander)                        402 non-null    object
#  18   White population with known age distribution                        402 non-null    object
#  19   0-15 years old of white race                                        402 non-null    object
#  20   a60wht                                                              402 non-null    object
#  21   Black population with known age distribution                        402 non-null    object
#  22   0-15 years old of Black race                                        402 non-null    object
#  23   a60blk                                                              402 non-null    object
#  24   Hispanic population with known age distribution                     402 non-null    object
#  25   0-15 years old, persons of Hispanic origins                         402 non-null    object
#  26   a60hsp                                                              402 non-null    object
#  27   Native American population with known age distribution              402 non-null    object
#  28   0-15 years old of Native American race                              402 non-null    object
#  29   a60ntv                                                              402 non-null    object
#  30   Asian and Pacific Islander population with known age distribution   402 non-null    object
#  31   0-15 years old of Asians and Pacific Islanders                      402 non-null    object
#  32   a60asn                                                              402 non-null    object
#  33   Foreign-born                                                        402 non-null    object
#  34   Recent immigrants (within the past 10 years)                        402 non-null    object
#  35   Naturalized foreign-born                                            402 non-null    object
#  36   Persons 5 years and over                                            402 non-null    object
#  37   Persons who speak language other than English at home               402 non-null    object
#  38   Persons who speak English not well                                  402 non-null    object
#  39   Population 25 years and over                                        402 non-null    object
#  40   Persons with high school degree or less                             402 non-null    object
#  41   Persons with at least a four-year college degree                    402 non-null    object
#  42   Civilian labor force 16 years and over                              402 non-null    object
#  43   Unemployed                                                          402 non-null    object
#  44   Females 16 years and over, except in armed forces                   402 non-null    object
#  45   Females in labor force                                              402 non-null    object
#  46   Employed persons 16 years and over                                  402 non-null    object
#  47   Professional employees (by occupations)                             402 non-null    object
#  48   Manufacturing employees (by industries)                             402 non-null    object
#  49   Self-employed                                                       402 non-null    object
#  50   Civilian population 18 years and over                               402 non-null    object
#  51   Veterans                                                            402 non-null    object
#  52   cni16u                                                              402 non-null    object
#  53   Disabled                                                            402 non-null    object
#  54   Median household income                                             400 non-null    object
#  55   Total households in sample-based data                               402 non-null    object
#  56   Median household income for whites                                  398 non-null    object
#  57   Total white households in sample-based data                         402 non-null    object
#  58   Median household income for Blacks                                  391 non-null    object
#  59   Total Black households in sample-based data                         402 non-null    object
#  60   Median household income for Hispanics                               353 non-null    object
#  61   Total Hispanic households in sample-based data                      402 non-null    object
#  62   Median household income for Native Americans                        0 non-null      object
#  63   Total Native American households in sample-based data               0 non-null      object
#  64   Median household income for Asians and Pacific Islanders            345 non-null    object
#  65   Total Asian/Pacific Islander households in sample-based data        402 non-null    object
#  66   Per capita income                                                   402 non-null    object
#  67   Persons for whom poverty status is determined                       402 non-null    object
#  68   Persons in poverty                                                  402 non-null    object
#  69   Persons 65 years and older in poverty                               402 non-null    object
#  70   Families for whom poverty status is determined                      402 non-null    object
#  71   Families with children in poverty                                   402 non-null    object
#  72   White persons for whom poverty status is determined                 402 non-null    object
#  73   Whites in poverty                                                   402 non-null    object
#  74   Black persons for whom poverty status is determined                 402 non-null    object
#  75   Blacks in poverty                                                   402 non-null    object
#  76   Hispanics for whom poverty status is determined                     402 non-null    object
#  77   Hispanics in poverty                                                402 non-null    object
#  78   Native Americans for whom poverty status is determined              402 non-null    object
#  79   Native Americans in poverty                                         402 non-null    object
#  80   Asians and Pacific Islanders for whom poverty status is determined  402 non-null    object
#  81   Asians and Pacific Islanders in poverty                             402 non-null    object
#  82   Housing units                                                       402 non-null    object
#  83   Vacant housing units                                                402 non-null    object
#  84   Occupied housing units                                              402 non-null    object
#  85   Owner-occupied housing units                                        402 non-null    object
#  86   Renter-occupied housing units                                       402 non-null    object
#  87   Total housing units                                                 402 non-null    object
#  88   Housing units in multi-unit structures                              402 non-null    object
#  89   Median home value                                                   400 non-null    object
#  90   Median monthly contract rent                                        400 non-null    object
#  91   Structures built more than 30 years ago                             402 non-null    object
#  92   Household heads moved into unit less than 10 years ago              402 non-null    object
#  93   Persons age 17 years and under                                      402 non-null    object
#  94   Persons age 60 years and over                                       402 non-null    object
#  95   Persons age 75 years and over                                       402 non-null    object
#  96   Population 15 years and over                                        402 non-null    object
#  97   Currently married (excluding separated)                             402 non-null    object
#  98   Widowed, divorced, and separated                                    402 non-null    object
#  99   Total families                                                      402 non-null    object
#  100  Female-headed families with children                                402 non-null    object
#  101  popsf3                                                              402 non-null    object
#  102  husp                                                                402 non-null    object
#  103  ohusp                                                               402 non-null    object
#  104  minority                                                            402 non-null    object
#  105  pmin                                                                400 non-null    object
#  106  pnhwht                                                              400 non-null    object
#  107  pnhblk                                                              400 non-null    object
#  108  phisp                                                               400 non-null    object
#  109  pntv                                                                400 non-null    object
#  110  pasian                                                              400 non-null    object
#  111  p15wht                                                              400 non-null    object
#  112  p65wht                                                              400 non-null    object
#  113  p15blk                                                              400 non-null    object
#  114  p65blk                                                              400 non-null    object
#  115  p15hsp                                                              400 non-null    object
#  116  p65hsp                                                              400 non-null    object
#  117  p15ntv                                                              379 non-null    object
#  118  p65ntv                                                              379 non-null    object
#  119  p15asn                                                              396 non-null    object
#  120  p65asn                                                              396 non-null    object
#  121  pfb                                                                 400 non-null    object
#  122  p10imm                                                              400 non-null    object
#  123  pnat                                                                400 non-null    object
#  124  polang                                                              400 non-null    object
#  125  plep                                                                400 non-null    object
#  126  phs                                                                 400 non-null    object
#  127  pcol                                                                400 non-null    object
#  128  punemp                                                              400 non-null    object
#  129  pflabf                                                              400 non-null    object
#  130  pprof                                                               400 non-null    object
#  131  pmanuf                                                              400 non-null    object
#  132  psemp                                                               400 non-null    object
#  133  pvet                                                                400 non-null    object
#  134  pdis                                                                400 non-null    object
#  135  ppov                                                                400 non-null    object
#  136  p65pov                                                              400 non-null    object
#  137  pfmpov                                                              400 non-null    object
#  138  pwpov                                                               400 non-null    object
#  139  pbpov                                                               398 non-null    object
#  140  phpov                                                               375 non-null    object
#  141  pnapov                                                              207 non-null    object
#  142  papov                                                               366 non-null    object
#  143  pvac                                                                400 non-null    object
#  144  pown                                                                400 non-null    object
#  145  pmulti                                                              400 non-null    object
#  146  p30old                                                              400 non-null    object
#  147  p10yrs                                                              400 non-null    object
#  148  p18und                                                              400 non-null    object
#  149  p60up                                                               400 non-null    object
#  150  p75up                                                               400 non-null    object
#  151  pmar                                                                400 non-null    object
#  152  pwds                                                                400 non-null    object
#  153  pfhh                                                                400 non-null    object
#  154  phhami                                                              400 non-null    object
#  155  phhcmi                                                              400 non-null    object
#  156  phhw                                                                400 non-null    object
#  157  phhwami                                                             398 non-null    object
#  158  phhwcmi                                                             398 non-null    object
#  159  phhb                                                                400 non-null    object
#  160  phhbami                                                             391 non-null    object
#  161  phhbcmi                                                             391 non-null    object
#  162  phhh                                                                400 non-null    object
#  163  phhhami                                                             353 non-null    object
#  164  phhhcmi                                                             353 non-null    object
#  165  phhn                                                                0 non-null      object
#  166  phhnami                                                             0 non-null      object
#  167  phhncmi                                                             0 non-null      object
#  168  phha                                                                400 non-null    object
#  169  phhaami                                                             345 non-null    object
#  170  phhacmi                                                             345 non-null    object
#  171  midami                                                              400 non-null    object
#  172  midcmi                                                              400 non-null    object
#  173  midmajami                                                           400 non-null    object
#  174  midmajcmi                                                           400 non-null    object
#  175  Year                                                                402 non-null    int64
#  176  65 years and older of non-Hispanic whites                           0 non-null      object
#  177  65 years and older of Black race                                    0 non-null      object
#  178  65 years and older, persons of Hispanic origins                     0 non-null      object
#  179  65 years and older of Native American race                          0 non-null      object
#  180  65 years and older of Asians and Pacific Islanders                  0 non-null      object
#  181  Civilian non-institutionalized persons 16-64 years old              0 non-null      object
# dtypes: int64(1), object(181)
# memory usage: 574.7+ KB

# %%
null_00 = [c for c in recent_data.columns if recent_00[c].isna().all()]
null_00
# Out:
# ['Median household income for Native Americans',
#  'Total Native American households in sample-based data',
#  'phhn',
#  'phhnami',
#  'phhncmi',
#  '65 years and older of non-Hispanic whites',
#  '65 years and older of Black race',
#  '65 years and older, persons of Hispanic origins',
#  '65 years and older of Native American race',
#  '65 years and older of Asians and Pacific Islanders',
#  'Civilian non-institutionalized persons 16-64 years old']

# %%
recent_12 = recent_data[recent_data['Year'] == 2012]
recent_12.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 397 entries, 1 to 397
# Data columns (total 182 columns):
#  #    Column                                                              Non-Null Count  Dtype
# ---   ------                                                              --------------  -----
#  0    Tract GEOID                                                         397 non-null    object
#  1    Tract name                                                          397 non-null    object
#  2    state                                                               397 non-null    object
#  3    county                                                              397 non-null    object
#  4    Place FIPS code                                                     307 non-null    object
#  5    placename                                                           307 non-null    object
#  6    CBSA FIPS code                                                      397 non-null    object
#  7    cbsaname                                                            397 non-null    object
#  8    Metropolitan (MSA) or micropolitan (µsa)                            397 non-null    object
#  9    Central or Outlying                                                 397 non-null    object
#  10   CBSA median income (2022$)                                          397 non-null    object
#  11   Principal city median income (2022$)                                397 non-null    object
#  12   Total population                                                    397 non-null    object
#  13   Persons of white race, not Hispanic origin                          397 non-null    object
#  14   Persons of black race, not Hispanic origin                          397 non-null    object
#  15   Persons of Hispanic origin                                          397 non-null    object
#  16   Persons of Native American race                                     397 non-null    object
#  17   Persons of Asian race (and Pacific Islander)                        397 non-null    object
#  18   White population with known age distribution                        397 non-null    object
#  19   0-15 years old of white race                                        397 non-null    object
#  20   a60wht                                                              397 non-null    object
#  21   Black population with known age distribution                        397 non-null    object
#  22   0-15 years old of Black race                                        397 non-null    object
#  23   a60blk                                                              397 non-null    object
#  24   Hispanic population with known age distribution                     397 non-null    object
#  25   0-15 years old, persons of Hispanic origins                         397 non-null    object
#  26   a60hsp                                                              397 non-null    object
#  27   Native American population with known age distribution              397 non-null    object
#  28   0-15 years old of Native American race                              397 non-null    object
#  29   a60ntv                                                              397 non-null    object
#  30   Asian and Pacific Islander population with known age distribution   397 non-null    object
#  31   0-15 years old of Asians and Pacific Islanders                      397 non-null    object
#  32   a60asn                                                              397 non-null    object
#  33   Foreign-born                                                        397 non-null    object
#  34   Recent immigrants (within the past 10 years)                        397 non-null    object
#  35   Naturalized foreign-born                                            397 non-null    object
#  36   Persons 5 years and over                                            397 non-null    object
#  37   Persons who speak language other than English at home               397 non-null    object
#  38   Persons who speak English not well                                  397 non-null    object
#  39   Population 25 years and over                                        397 non-null    object
#  40   Persons with high school degree or less                             397 non-null    object
#  41   Persons with at least a four-year college degree                    397 non-null    object
#  42   Civilian labor force 16 years and over                              397 non-null    object
#  43   Unemployed                                                          397 non-null    object
#  44   Females 16 years and over, except in armed forces                   397 non-null    object
#  45   Females in labor force                                              397 non-null    object
#  46   Employed persons 16 years and over                                  397 non-null    object
#  47   Professional employees (by occupations)                             397 non-null    object
#  48   Manufacturing employees (by industries)                             397 non-null    object
#  49   Self-employed                                                       397 non-null    object
#  50   Civilian population 18 years and over                               397 non-null    object
#  51   Veterans                                                            397 non-null    object
#  52   cni16u                                                              397 non-null    object
#  53   Disabled                                                            397 non-null    object
#  54   Median household income                                             393 non-null    object
#  55   Total households in sample-based data                               397 non-null    object
#  56   Median household income for whites                                  385 non-null    object
#  57   Total white households in sample-based data                         397 non-null    object
#  58   Median household income for Blacks                                  295 non-null    object
#  59   Total Black households in sample-based data                         397 non-null    object
#  60   Median household income for Hispanics                               152 non-null    object
#  61   Total Hispanic households in sample-based data                      397 non-null    object
#  62   Median household income for Native Americans                        12 non-null     object
#  63   Total Native American households in sample-based data               397 non-null    object
#  64   Median household income for Asians and Pacific Islanders            153 non-null    object
#  65   Total Asian/Pacific Islander households in sample-based data        397 non-null    object
#  66   Per capita income                                                   394 non-null    object
#  67   Persons for whom poverty status is determined                       397 non-null    object
#  68   Persons in poverty                                                  397 non-null    object
#  69   Persons 65 years and older in poverty                               397 non-null    object
#  70   Families for whom poverty status is determined                      397 non-null    object
#  71   Families with children in poverty                                   397 non-null    object
#  72   White persons for whom poverty status is determined                 397 non-null    object
#  73   Whites in poverty                                                   397 non-null    object
#  74   Black persons for whom poverty status is determined                 397 non-null    object
#  75   Blacks in poverty                                                   397 non-null    object
#  76   Hispanics for whom poverty status is determined                     397 non-null    object
#  77   Hispanics in poverty                                                397 non-null    object
#  78   Native Americans for whom poverty status is determined              397 non-null    object
#  79   Native Americans in poverty                                         397 non-null    object
#  80   Asians and Pacific Islanders for whom poverty status is determined  397 non-null    object
#  81   Asians and Pacific Islanders in poverty                             397 non-null    object
#  82   Housing units                                                       397 non-null    object
#  83   Vacant housing units                                                397 non-null    object
#  84   Occupied housing units                                              397 non-null    object
#  85   Owner-occupied housing units                                        397 non-null    object
#  86   Renter-occupied housing units                                       397 non-null    object
#  87   Total housing units                                                 397 non-null    object
#  88   Housing units in multi-unit structures                              397 non-null    object
#  89   Median home value                                                   389 non-null    object
#  90   Median monthly contract rent                                        387 non-null    object
#  91   Structures built more than 30 years ago                             397 non-null    object
#  92   Household heads moved into unit less than 10 years ago              397 non-null    object
#  93   Persons age 17 years and under                                      397 non-null    object
#  94   Persons age 60 years and over                                       397 non-null    object
#  95   Persons age 75 years and over                                       397 non-null    object
#  96   Population 15 years and over                                        397 non-null    object
#  97   Currently married (excluding separated)                             397 non-null    object
#  98   Widowed, divorced, and separated                                    397 non-null    object
#  99   Total families                                                      397 non-null    object
#  100  Female-headed families with children                                397 non-null    object
#  101  popsf3                                                              0 non-null      object
#  102  husp                                                                0 non-null      object
#  103  ohusp                                                               0 non-null      object
#  104  minority                                                            397 non-null    object
#  105  pmin                                                                397 non-null    object
#  106  pnhwht                                                              397 non-null    object
#  107  pnhblk                                                              397 non-null    object
#  108  phisp                                                               397 non-null    object
#  109  pntv                                                                397 non-null    object
#  110  pasian                                                              397 non-null    object
#  111  p15wht                                                              397 non-null    object
#  112  p65wht                                                              397 non-null    object
#  113  p15blk                                                              375 non-null    object
#  114  p65blk                                                              375 non-null    object
#  115  p15hsp                                                              329 non-null    object
#  116  p65hsp                                                              329 non-null    object
#  117  p15ntv                                                              121 non-null    object
#  118  p65ntv                                                              121 non-null    object
#  119  p15asn                                                              272 non-null    object
#  120  p65asn                                                              272 non-null    object
#  121  pfb                                                                 397 non-null    object
#  122  p10imm                                                              397 non-null    object
#  123  pnat                                                                397 non-null    object
#  124  polang                                                              397 non-null    object
#  125  plep                                                                397 non-null    object
#  126  phs                                                                 397 non-null    object
#  127  pcol                                                                397 non-null    object
#  128  punemp                                                              395 non-null    object
#  129  pflabf                                                              394 non-null    object
#  130  pprof                                                               395 non-null    object
#  131  pmanuf                                                              395 non-null    object
#  132  psemp                                                               395 non-null    object
#  133  pvet                                                                397 non-null    object
#  134  pdis                                                                396 non-null    object
#  135  ppov                                                                396 non-null    object
#  136  p65pov                                                              396 non-null    object
#  137  pfmpov                                                              394 non-null    object
#  138  pwpov                                                               396 non-null    object
#  139  pbpov                                                               369 non-null    object
#  140  phpov                                                               323 non-null    object
#  141  pnapov                                                              118 non-null    object
#  142  papov                                                               268 non-null    object
#  143  pvac                                                                396 non-null    object
#  144  pown                                                                396 non-null    object
#  145  pmulti                                                              396 non-null    object
#  146  p30old                                                              396 non-null    object
#  147  p10yrs                                                              396 non-null    object
#  148  p18und                                                              397 non-null    object
#  149  p60up                                                               397 non-null    object
#  150  p75up                                                               397 non-null    object
#  151  pmar                                                                397 non-null    object
#  152  pwds                                                                397 non-null    object
#  153  pfhh                                                                394 non-null    object
#  154  phhami                                                              393 non-null    object
#  155  phhcmi                                                              393 non-null    object
#  156  phhw                                                                396 non-null    object
#  157  phhwami                                                             385 non-null    object
#  158  phhwcmi                                                             385 non-null    object
#  159  phhb                                                                396 non-null    object
#  160  phhbami                                                             295 non-null    object
#  161  phhbcmi                                                             295 non-null    object
#  162  phhh                                                                396 non-null    object
#  163  phhhami                                                             152 non-null    object
#  164  phhhcmi                                                             152 non-null    object
#  165  phhn                                                                396 non-null    object
#  166  phhnami                                                             12 non-null     object
#  167  phhncmi                                                             12 non-null     object
#  168  phha                                                                396 non-null    object
#  169  phhaami                                                             153 non-null    object
#  170  phhacmi                                                             153 non-null    object
#  171  midami                                                              393 non-null    object
#  172  midcmi                                                              393 non-null    object
#  173  midmajami                                                           393 non-null    object
#  174  midmajcmi                                                           393 non-null    object
#  175  Year                                                                397 non-null    int64
#  176  65 years and older of non-Hispanic whites                           0 non-null      object
#  177  65 years and older of Black race                                    0 non-null      object
#  178  65 years and older, persons of Hispanic origins                     0 non-null      object
#  179  65 years and older of Native American race                          0 non-null      object
#  180  65 years and older of Asians and Pacific Islanders                  0 non-null      object
#  181  Civilian non-institutionalized persons 16-64 years old              0 non-null      object
# dtypes: int64(1), object(181)
# memory usage: 567.6+ KB

# %%
null_12 = [c for c in recent_data.columns if recent_12[c].isna().all()]
null_12
# Out:
# ['popsf3',
#  'husp',
#  'ohusp',
#  '65 years and older of non-Hispanic whites',
#  '65 years and older of Black race',
#  '65 years and older, persons of Hispanic origins',
#  '65 years and older of Native American race',
#  '65 years and older of Asians and Pacific Islanders',
#  'Civilian non-institutionalized persons 16-64 years old']

# %%
recent_22 = recent_data[recent_data['Year'] == 2022]
recent_22.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 386 entries, 1 to 386
# Data columns (total 182 columns):
#  #    Column                                                              Non-Null Count  Dtype
# ---   ------                                                              --------------  -----
#  0    Tract GEOID                                                         386 non-null    object
#  1    Tract name                                                          386 non-null    object
#  2    state                                                               386 non-null    object
#  3    county                                                              386 non-null    object
#  4    Place FIPS code                                                     386 non-null    object
#  5    placename                                                           285 non-null    object
#  6    CBSA FIPS code                                                      386 non-null    object
#  7    cbsaname                                                            386 non-null    object
#  8    Metropolitan (MSA) or micropolitan (µsa)                            386 non-null    object
#  9    Central or Outlying                                                 386 non-null    object
#  10   CBSA median income (2022$)                                          386 non-null    object
#  11   Principal city median income (2022$)                                386 non-null    object
#  12   Total population                                                    386 non-null    object
#  13   Persons of white race, not Hispanic origin                          386 non-null    object
#  14   Persons of black race, not Hispanic origin                          386 non-null    object
#  15   Persons of Hispanic origin                                          386 non-null    object
#  16   Persons of Native American race                                     386 non-null    object
#  17   Persons of Asian race (and Pacific Islander)                        386 non-null    object
#  18   White population with known age distribution                        386 non-null    object
#  19   0-15 years old of white race                                        386 non-null    object
#  20   a60wht                                                              0 non-null      object
#  21   Black population with known age distribution                        386 non-null    object
#  22   0-15 years old of Black race                                        386 non-null    object
#  23   a60blk                                                              0 non-null      object
#  24   Hispanic population with known age distribution                     386 non-null    object
#  25   0-15 years old, persons of Hispanic origins                         386 non-null    object
#  26   a60hsp                                                              0 non-null      object
#  27   Native American population with known age distribution              386 non-null    object
#  28   0-15 years old of Native American race                              386 non-null    object
#  29   a60ntv                                                              0 non-null      object
#  30   Asian and Pacific Islander population with known age distribution   386 non-null    object
#  31   0-15 years old of Asians and Pacific Islanders                      386 non-null    object
#  32   a60asn                                                              0 non-null      object
#  33   Foreign-born                                                        386 non-null    object
#  34   Recent immigrants (within the past 10 years)                        386 non-null    object
#  35   Naturalized foreign-born                                            386 non-null    object
#  36   Persons 5 years and over                                            386 non-null    object
#  37   Persons who speak language other than English at home               386 non-null    object
#  38   Persons who speak English not well                                  386 non-null    object
#  39   Population 25 years and over                                        386 non-null    object
#  40   Persons with high school degree or less                             386 non-null    object
#  41   Persons with at least a four-year college degree                    386 non-null    object
#  42   Civilian labor force 16 years and over                              386 non-null    object
#  43   Unemployed                                                          386 non-null    object
#  44   Females 16 years and over, except in armed forces                   386 non-null    object
#  45   Females in labor force                                              386 non-null    object
#  46   Employed persons 16 years and over                                  386 non-null    object
#  47   Professional employees (by occupations)                             386 non-null    object
#  48   Manufacturing employees (by industries)                             386 non-null    object
#  49   Self-employed                                                       386 non-null    object
#  50   Civilian population 18 years and over                               386 non-null    object
#  51   Veterans                                                            386 non-null    object
#  52   cni16u                                                              0 non-null      object
#  53   Disabled                                                            386 non-null    object
#  54   Median household income                                             381 non-null    object
#  55   Total households in sample-based data                               386 non-null    object
#  56   Median household income for whites                                  368 non-null    object
#  57   Total white households in sample-based data                         386 non-null    object
#  58   Median household income for Blacks                                  178 non-null    object
#  59   Total Black households in sample-based data                         386 non-null    object
#  60   Median household income for Hispanics                               57 non-null     object
#  61   Total Hispanic households in sample-based data                      386 non-null    object
#  62   Median household income for Native Americans                        0 non-null      object
#  63   Total Native American households in sample-based data               386 non-null    object
#  64   Median household income for Asians and Pacific Islanders            90 non-null     object
#  65   Total Asian/Pacific Islander households in sample-based data        386 non-null    object
#  66   Per capita income                                                   386 non-null    object
#  67   Persons for whom poverty status is determined                       386 non-null    object
#  68   Persons in poverty                                                  386 non-null    object
#  69   Persons 65 years and older in poverty                               386 non-null    object
#  70   Families for whom poverty status is determined                      386 non-null    object
#  71   Families with children in poverty                                   386 non-null    object
#  72   White persons for whom poverty status is determined                 386 non-null    object
#  73   Whites in poverty                                                   386 non-null    object
#  74   Black persons for whom poverty status is determined                 386 non-null    object
#  75   Blacks in poverty                                                   386 non-null    object
#  76   Hispanics for whom poverty status is determined                     386 non-null    object
#  77   Hispanics in poverty                                                386 non-null    object
#  78   Native Americans for whom poverty status is determined              386 non-null    object
#  79   Native Americans in poverty                                         386 non-null    object
#  80   Asians and Pacific Islanders for whom poverty status is determined  386 non-null    object
#  81   Asians and Pacific Islanders in poverty                             386 non-null    object
#  82   Housing units                                                       386 non-null    object
#  83   Vacant housing units                                                386 non-null    object
#  84   Occupied housing units                                              386 non-null    object
#  85   Owner-occupied housing units                                        386 non-null    object
#  86   Renter-occupied housing units                                       386 non-null    object
#  87   Total housing units                                                 386 non-null    object
#  88   Housing units in multi-unit structures                              386 non-null    object
#  89   Median home value                                                   375 non-null    object
#  90   Median monthly contract rent                                        369 non-null    object
#  91   Structures built more than 30 years ago                             386 non-null    object
#  92   Household heads moved into unit less than 10 years ago              386 non-null    object
#  93   Persons age 17 years and under                                      386 non-null    object
#  94   Persons age 60 years and over                                       386 non-null    object
#  95   Persons age 75 years and over                                       386 non-null    object
#  96   Population 15 years and over                                        386 non-null    object
#  97   Currently married (excluding separated)                             386 non-null    object
#  98   Widowed, divorced, and separated                                    386 non-null    object
#  99   Total families                                                      386 non-null    object
#  100  Female-headed families with children                                386 non-null    object
#  101  popsf3                                                              0 non-null      object
#  102  husp                                                                0 non-null      object
#  103  ohusp                                                               0 non-null      object
#  104  minority                                                            386 non-null    object
#  105  pmin                                                                386 non-null    object
#  106  pnhwht                                                              386 non-null    object
#  107  pnhblk                                                              386 non-null    object
#  108  phisp                                                               386 non-null    object
#  109  pntv                                                                386 non-null    object
#  110  pasian                                                              386 non-null    object
#  111  p15wht                                                              386 non-null    object
#  112  p65wht                                                              386 non-null    object
#  113  p15blk                                                              370 non-null    object
#  114  p65blk                                                              370 non-null    object
#  115  p15hsp                                                              348 non-null    object
#  116  p65hsp                                                              348 non-null    object
#  117  p15ntv                                                              89 non-null     object
#  118  p65ntv                                                              89 non-null     object
#  119  p15asn                                                              301 non-null    object
#  120  p65asn                                                              301 non-null    object
#  121  pfb                                                                 386 non-null    object
#  122  p10imm                                                              386 non-null    object
#  123  pnat                                                                386 non-null    object
#  124  polang                                                              386 non-null    object
#  125  plep                                                                386 non-null    object
#  126  phs                                                                 386 non-null    object
#  127  pcol                                                                386 non-null    object
#  128  punemp                                                              383 non-null    object
#  129  pflabf                                                              385 non-null    object
#  130  pprof                                                               383 non-null    object
#  131  pmanuf                                                              383 non-null    object
#  132  psemp                                                               383 non-null    object
#  133  pvet                                                                386 non-null    object
#  134  pdis                                                                384 non-null    object
#  135  ppov                                                                384 non-null    object
#  136  p65pov                                                              384 non-null    object
#  137  pfmpov                                                              382 non-null    object
#  138  pwpov                                                               384 non-null    object
#  139  pbpov                                                               362 non-null    object
#  140  phpov                                                               345 non-null    object
#  141  pnapov                                                              84 non-null     object
#  142  papov                                                               294 non-null    object
#  143  pvac                                                                383 non-null    object
#  144  pown                                                                383 non-null    object
#  145  pmulti                                                              383 non-null    object
#  146  p30old                                                              383 non-null    object
#  147  p10yrs                                                              383 non-null    object
#  148  p18und                                                              386 non-null    object
#  149  p60up                                                               386 non-null    object
#  150  p75up                                                               386 non-null    object
#  151  pmar                                                                386 non-null    object
#  152  pwds                                                                386 non-null    object
#  153  pfhh                                                                382 non-null    object
#  154  phhami                                                              381 non-null    object
#  155  phhcmi                                                              381 non-null    object
#  156  phhw                                                                383 non-null    object
#  157  phhwami                                                             368 non-null    object
#  158  phhwcmi                                                             368 non-null    object
#  159  phhb                                                                383 non-null    object
#  160  phhbami                                                             178 non-null    object
#  161  phhbcmi                                                             178 non-null    object
#  162  phhh                                                                383 non-null    object
#  163  phhhami                                                             57 non-null     object
#  164  phhhcmi                                                             57 non-null     object
#  165  phhn                                                                383 non-null    object
#  166  phhnami                                                             0 non-null      object
#  167  phhncmi                                                             0 non-null      object
#  168  phha                                                                383 non-null    object
#  169  phhaami                                                             90 non-null     object
#  170  phhacmi                                                             90 non-null     object
#  171  midami                                                              381 non-null    object
#  172  midcmi                                                              381 non-null    object
#  173  midmajami                                                           381 non-null    object
#  174  midmajcmi                                                           381 non-null    object
#  175  Year                                                                386 non-null    int64
#  176  65 years and older of non-Hispanic whites                           386 non-null    object
#  177  65 years and older of Black race                                    386 non-null    object
#  178  65 years and older, persons of Hispanic origins                     386 non-null    object
#  179  65 years and older of Native American race                          386 non-null    object
#  180  65 years and older of Asians and Pacific Islanders                  386 non-null    object
#  181  Civilian non-institutionalized persons 16-64 years old              386 non-null    object
# dtypes: int64(1), object(181)
# memory usage: 551.9+ KB

# %%
null_22 = [c for c in recent_data.columns if recent_22[c].isna().all()]
null_22
# Out:
# ['a60wht',
#  'a60blk',
#  'a60hsp',
#  'a60ntv',
#  'a60asn',
#  'cni16u',
#  'Median household income for Native Americans',
#  'popsf3',
#  'husp',
#  'ohusp',
#  'phhnami',
#  'phhncmi']

# %%
# Remove columns that are totally null for a whole year

recent_data = recent_data.drop(columns=list(set(null_00 + null_12 + null_22)))

# %%
recent_data.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1185 entries, 1 to 386
# Data columns (total 162 columns):
#  #    Column                                                              Non-Null Count  Dtype
# ---   ------                                                              --------------  -----
#  0    Tract GEOID                                                         1185 non-null   object
#  1    Tract name                                                          1185 non-null   object
#  2    state                                                               1185 non-null   object
#  3    county                                                              1185 non-null   object
#  4    Place FIPS code                                                     1005 non-null   object
#  5    placename                                                           904 non-null    object
#  6    CBSA FIPS code                                                      1185 non-null   object
#  7    cbsaname                                                            1185 non-null   object
#  8    Metropolitan (MSA) or micropolitan (µsa)                            1185 non-null   object
#  9    Central or Outlying                                                 1185 non-null   object
#  10   CBSA median income (2022$)                                          1185 non-null   object
#  11   Principal city median income (2022$)                                1185 non-null   object
#  12   Total population                                                    1185 non-null   object
#  13   Persons of white race, not Hispanic origin                          1185 non-null   object
#  14   Persons of black race, not Hispanic origin                          1185 non-null   object
#  15   Persons of Hispanic origin                                          1185 non-null   object
#  16   Persons of Native American race                                     1185 non-null   object
#  17   Persons of Asian race (and Pacific Islander)                        1185 non-null   object
#  18   White population with known age distribution                        1185 non-null   object
#  19   0-15 years old of white race                                        1185 non-null   object
#  20   Black population with known age distribution                        1185 non-null   object
#  21   0-15 years old of Black race                                        1185 non-null   object
#  22   Hispanic population with known age distribution                     1185 non-null   object
#  23   0-15 years old, persons of Hispanic origins                         1185 non-null   object
#  24   Native American population with known age distribution              1185 non-null   object
#  25   0-15 years old of Native American race                              1185 non-null   object
#  26   Asian and Pacific Islander population with known age distribution   1185 non-null   object
#  27   0-15 years old of Asians and Pacific Islanders                      1185 non-null   object
#  28   Foreign-born                                                        1185 non-null   object
#  29   Recent immigrants (within the past 10 years)                        1185 non-null   object
#  30   Naturalized foreign-born                                            1185 non-null   object
#  31   Persons 5 years and over                                            1185 non-null   object
#  32   Persons who speak language other than English at home               1185 non-null   object
#  33   Persons who speak English not well                                  1185 non-null   object
#  34   Population 25 years and over                                        1185 non-null   object
#  35   Persons with high school degree or less                             1185 non-null   object
#  36   Persons with at least a four-year college degree                    1185 non-null   object
#  37   Civilian labor force 16 years and over                              1185 non-null   object
#  38   Unemployed                                                          1185 non-null   object
#  39   Females 16 years and over, except in armed forces                   1185 non-null   object
#  40   Females in labor force                                              1185 non-null   object
#  41   Employed persons 16 years and over                                  1185 non-null   object
#  42   Professional employees (by occupations)                             1185 non-null   object
#  43   Manufacturing employees (by industries)                             1185 non-null   object
#  44   Self-employed                                                       1185 non-null   object
#  45   Civilian population 18 years and over                               1185 non-null   object
#  46   Veterans                                                            1185 non-null   object
#  47   Disabled                                                            1185 non-null   object
#  48   Median household income                                             1174 non-null   object
#  49   Total households in sample-based data                               1185 non-null   object
#  50   Median household income for whites                                  1151 non-null   object
#  51   Total white households in sample-based data                         1185 non-null   object
#  52   Median household income for Blacks                                  864 non-null    object
#  53   Total Black households in sample-based data                         1185 non-null   object
#  54   Median household income for Hispanics                               562 non-null    object
#  55   Total Hispanic households in sample-based data                      1185 non-null   object
#  56   Median household income for Asians and Pacific Islanders            588 non-null    object
#  57   Total Asian/Pacific Islander households in sample-based data        1185 non-null   object
#  58   Per capita income                                                   1182 non-null   object
#  59   Persons for whom poverty status is determined                       1185 non-null   object
#  60   Persons in poverty                                                  1185 non-null   object
#  61   Persons 65 years and older in poverty                               1185 non-null   object
#  62   Families for whom poverty status is determined                      1185 non-null   object
#  63   Families with children in poverty                                   1185 non-null   object
#  64   White persons for whom poverty status is determined                 1185 non-null   object
#  65   Whites in poverty                                                   1185 non-null   object
#  66   Black persons for whom poverty status is determined                 1185 non-null   object
#  67   Blacks in poverty                                                   1185 non-null   object
#  68   Hispanics for whom poverty status is determined                     1185 non-null   object
#  69   Hispanics in poverty                                                1185 non-null   object
#  70   Native Americans for whom poverty status is determined              1185 non-null   object
#  71   Native Americans in poverty                                         1185 non-null   object
#  72   Asians and Pacific Islanders for whom poverty status is determined  1185 non-null   object
#  73   Asians and Pacific Islanders in poverty                             1185 non-null   object
#  74   Housing units                                                       1185 non-null   object
#  75   Vacant housing units                                                1185 non-null   object
#  76   Occupied housing units                                              1185 non-null   object
#  77   Owner-occupied housing units                                        1185 non-null   object
#  78   Renter-occupied housing units                                       1185 non-null   object
#  79   Total housing units                                                 1185 non-null   object
#  80   Housing units in multi-unit structures                              1185 non-null   object
#  81   Median home value                                                   1164 non-null   object
#  82   Median monthly contract rent                                        1156 non-null   object
#  83   Structures built more than 30 years ago                             1185 non-null   object
#  84   Household heads moved into unit less than 10 years ago              1185 non-null   object
#  85   Persons age 17 years and under                                      1185 non-null   object
#  86   Persons age 60 years and over                                       1185 non-null   object
#  87   Persons age 75 years and over                                       1185 non-null   object
#  88   Population 15 years and over                                        1185 non-null   object
#  89   Currently married (excluding separated)                             1185 non-null   object
#  90   Widowed, divorced, and separated                                    1185 non-null   object
#  91   Total families                                                      1185 non-null   object
#  92   Female-headed families with children                                1185 non-null   object
#  93   minority                                                            1185 non-null   object
#  94   pmin                                                                1183 non-null   object
#  95   pnhwht                                                              1183 non-null   object
#  96   pnhblk                                                              1183 non-null   object
#  97   phisp                                                               1183 non-null   object
#  98   pntv                                                                1183 non-null   object
#  99   pasian                                                              1183 non-null   object
#  100  p15wht                                                              1183 non-null   object
#  101  p65wht                                                              1183 non-null   object
#  102  p15blk                                                              1145 non-null   object
#  103  p65blk                                                              1145 non-null   object
#  104  p15hsp                                                              1077 non-null   object
#  105  p65hsp                                                              1077 non-null   object
#  106  p15ntv                                                              589 non-null    object
#  107  p65ntv                                                              589 non-null    object
#  108  p15asn                                                              969 non-null    object
#  109  p65asn                                                              969 non-null    object
#  110  pfb                                                                 1183 non-null   object
#  111  p10imm                                                              1183 non-null   object
#  112  pnat                                                                1183 non-null   object
#  113  polang                                                              1183 non-null   object
#  114  plep                                                                1183 non-null   object
#  115  phs                                                                 1183 non-null   object
#  116  pcol                                                                1183 non-null   object
#  117  punemp                                                              1178 non-null   object
#  118  pflabf                                                              1179 non-null   object
#  119  pprof                                                               1178 non-null   object
#  120  pmanuf                                                              1178 non-null   object
#  121  psemp                                                               1178 non-null   object
#  122  pvet                                                                1183 non-null   object
#  123  pdis                                                                1180 non-null   object
#  124  ppov                                                                1180 non-null   object
#  125  p65pov                                                              1180 non-null   object
#  126  pfmpov                                                              1176 non-null   object
#  127  pwpov                                                               1180 non-null   object
#  128  pbpov                                                               1129 non-null   object
#  129  phpov                                                               1043 non-null   object
#  130  pnapov                                                              409 non-null    object
#  131  papov                                                               928 non-null    object
#  132  pvac                                                                1179 non-null   object
#  133  pown                                                                1179 non-null   object
#  134  pmulti                                                              1179 non-null   object
#  135  p30old                                                              1179 non-null   object
#  136  p10yrs                                                              1179 non-null   object
#  137  p18und                                                              1183 non-null   object
#  138  p60up                                                               1183 non-null   object
#  139  p75up                                                               1183 non-null   object
#  140  pmar                                                                1183 non-null   object
#  141  pwds                                                                1183 non-null   object
#  142  pfhh                                                                1176 non-null   object
#  143  phhami                                                              1174 non-null   object
#  144  phhcmi                                                              1174 non-null   object
#  145  phhw                                                                1179 non-null   object
#  146  phhwami                                                             1151 non-null   object
#  147  phhwcmi                                                             1151 non-null   object
#  148  phhb                                                                1179 non-null   object
#  149  phhbami                                                             864 non-null    object
#  150  phhbcmi                                                             864 non-null    object
#  151  phhh                                                                1179 non-null   object
#  152  phhhami                                                             562 non-null    object
#  153  phhhcmi                                                             562 non-null    object
#  154  phha                                                                1179 non-null   object
#  155  phhaami                                                             588 non-null    object
#  156  phhacmi                                                             588 non-null    object
#  157  midami                                                              1174 non-null   object
#  158  midcmi                                                              1174 non-null   object
#  159  midmajami                                                           1174 non-null   object
#  160  midmajcmi                                                           1174 non-null   object
#  161  Year                                                                1185 non-null   int64
# dtypes: int64(1), object(161)
# memory usage: 1.5+ MB

# %%
for c in recent_data.columns:
    print('\''+c+'\',')
# Out:
# 'Tract GEOID',
# 'Tract name',
# 'state',
# 'county',
# 'Place FIPS code',
# 'placename',
# 'CBSA FIPS code',
# 'cbsaname',
# 'Metropolitan (MSA) or micropolitan (µsa)',
# 'Central or Outlying',
# 'CBSA median income (2022$)',
# 'Principal city median income (2022$)',
# 'Total population',
# 'Persons of white race, not Hispanic origin',
# 'Persons of black race, not Hispanic origin',
# 'Persons of Hispanic origin',
# 'Persons of Native American race',
# 'Persons of Asian race (and Pacific Islander)',
# 'White population with known age distribution',
# '0-15 years old of white race',
# 'Black population with known age distribution',
# '0-15 years old of Black race',
# 'Hispanic population with known age distribution',
# '0-15 years old, persons of Hispanic origins',
# 'Native American population with known age distribution',
# '0-15 years old of Native American race',
# 'Asian and Pacific Islander population with known age distribution',
# '0-15 years old of Asians and Pacific Islanders',
# 'Foreign-born',
# 'Recent immigrants (within the past 10 years)',
# 'Naturalized foreign-born',
# 'Persons 5 years and over',
# 'Persons who speak language other than English at home',
# 'Persons who speak English not well',
# 'Population 25 years and over',
# 'Persons with high school degree or less',
# 'Persons with at least a four-year college degree',
# 'Civilian labor force 16 years and over',
# 'Unemployed',
# 'Females 16 years and over, except in armed forces',
# 'Females in labor force',
# 'Employed persons 16 years and over',
# 'Professional employees (by occupations)',
# 'Manufacturing employees (by industries)',
# 'Self-employed',
# 'Civilian population 18 years and over',
# 'Veterans',
# 'Disabled',
# 'Median household income',
# 'Total households in sample-based data',
# 'Median household income for whites',
# 'Total white households in sample-based data',
# 'Median household income for Blacks',
# 'Total Black households in sample-based data',
# 'Median household income for Hispanics',
# 'Total Hispanic households in sample-based data',
# 'Median household income for Asians and Pacific Islanders',
# 'Total Asian/Pacific Islander households in sample-based data',
# 'Per capita income',
# 'Persons for whom poverty status is determined',
# 'Persons in poverty',
# 'Persons 65 years and older in poverty',
# 'Families for whom poverty status is determined',
# 'Families with children in poverty',
# 'White persons for whom poverty status is determined',
# 'Whites in poverty',
# 'Black persons for whom poverty status is determined',
# 'Blacks in poverty',
# 'Hispanics for whom poverty status is determined',
# 'Hispanics in poverty',
# 'Native Americans for whom poverty status is determined',
# 'Native Americans in poverty',
# 'Asians and Pacific Islanders for whom poverty status is determined',
# 'Asians and Pacific Islanders in poverty',
# 'Housing units',
# 'Vacant housing units',
# 'Occupied housing units',
# 'Owner-occupied housing units',
# 'Renter-occupied housing units',
# 'Total housing units',
# 'Housing units in multi-unit structures',
# 'Median home value',
# 'Median monthly contract rent',
# 'Structures built more than 30 years ago',
# 'Household heads moved into unit less than 10 years ago',
# 'Persons age 17 years and under',
# 'Persons age 60 years and over',
# 'Persons age 75 years and over',
# 'Population 15 years and over',
# 'Currently married (excluding separated)',
# 'Widowed, divorced, and separated',
# 'Total families',
# 'Female-headed families with children',
# 'minority',
# 'pmin',
# 'pnhwht',
# 'pnhblk',
# 'phisp',
# 'pntv',
# 'pasian',
# 'p15wht',
# 'p65wht',
# 'p15blk',
# 'p65blk',
# 'p15hsp',
# 'p65hsp',
# 'p15ntv',
# 'p65ntv',
# 'p15asn',
# 'p65asn',
# 'pfb',
# 'p10imm',
# 'pnat',
# 'polang',
# 'plep',
# 'phs',
# 'pcol',
# 'punemp',
# 'pflabf',
# 'pprof',
# 'pmanuf',
# 'psemp',
# 'pvet',
# 'pdis',
# 'ppov',
# 'p65pov',
# 'pfmpov',
# 'pwpov',
# 'pbpov',
# 'phpov',
# 'pnapov',
# 'papov',
# 'pvac',
# 'pown',
# 'pmulti',
# 'p30old',
# 'p10yrs',
# 'p18und',
# 'p60up',
# 'p75up',
# 'pmar',
# 'pwds',
# 'pfhh',
# 'phhami',
# 'phhcmi',
# 'phhw',
# 'phhwami',
# 'phhwcmi',
# 'phhb',
# 'phhbami',
# 'phhbcmi',
# 'phhh',
# 'phhhami',
# 'phhhcmi',
# 'phha',
# 'phhaami',
# 'phhacmi',
# 'midami',
# 'midcmi',
# 'midmajami',
# 'midmajcmi',
# 'Year',

# %%
relevant_data = recent_data[['Year','Tract GEOID',
'Tract name',
'state',
'county',
'Place FIPS code',
'CBSA FIPS code',
'cbsaname',
'Metropolitan (MSA) or micropolitan (µsa)',
'Central or Outlying',
'CBSA median income (2022$)',
'Principal city median income (2022$)',
'Total population',
'Persons of white race, not Hispanic origin',
'Persons of black race, not Hispanic origin',
'Persons of Hispanic origin',
'Persons of Native American race',
'Persons of Asian race (and Pacific Islander)',
'Foreign-born',
'Recent immigrants (within the past 10 years)',
'Naturalized foreign-born',
'Persons 5 years and over',
'Persons who speak language other than English at home',
'Persons who speak English not well',
'Population 25 years and over',
'Persons with high school degree or less',
'Persons with at least a four-year college degree',
'Civilian labor force 16 years and over',
'Unemployed',
'Females 16 years and over, except in armed forces',
'Females in labor force',
'Employed persons 16 years and over',
'Professional employees (by occupations)',
'Manufacturing employees (by industries)',
'Self-employed',
'Civilian population 18 years and over',
'Veterans',
'Disabled',
'Median household income',
'Total households in sample-based data',
'Median household income for whites',
'Total white households in sample-based data',
'Median household income for Blacks',
'Total Black households in sample-based data',
'Median household income for Hispanics',
'Total Hispanic households in sample-based data',
'Median household income for Asians and Pacific Islanders',
'Total Asian/Pacific Islander households in sample-based data',
'Per capita income',
'Persons for whom poverty status is determined',
'Persons in poverty',
'Persons 65 years and older in poverty',
'Families for whom poverty status is determined',
'Families with children in poverty',
'White persons for whom poverty status is determined',
'Whites in poverty',
'Black persons for whom poverty status is determined',
'Blacks in poverty',
'Hispanics for whom poverty status is determined',
'Hispanics in poverty',
'Native Americans for whom poverty status is determined',
'Native Americans in poverty',
'Asians and Pacific Islanders for whom poverty status is determined',
'Asians and Pacific Islanders in poverty',
'Housing units',
'Vacant housing units',
'Occupied housing units',
'Owner-occupied housing units',
'Renter-occupied housing units',
'Total housing units',
'Housing units in multi-unit structures',
'Median home value',
'Median monthly contract rent',
'Structures built more than 30 years ago',
'Household heads moved into unit less than 10 years ago',
'Persons age 17 years and under',
'Persons age 60 years and over',
'Persons age 75 years and over',
'Population 15 years and over',
'Currently married (excluding separated)',
'Widowed, divorced, and separated',
'Total families',
'Female-headed families with children']]

# %%
relevant_data.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1185 entries, 1 to 386
# Data columns (total 83 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Year                                                                1185 non-null   int64
#  1   Tract GEOID                                                         1185 non-null   object
#  2   Tract name                                                          1185 non-null   object
#  3   state                                                               1185 non-null   object
#  4   county                                                              1185 non-null   object
#  5   Place FIPS code                                                     1005 non-null   object
#  6   CBSA FIPS code                                                      1185 non-null   object
#  7   cbsaname                                                            1185 non-null   object
#  8   Metropolitan (MSA) or micropolitan (µsa)                            1185 non-null   object
#  9   Central or Outlying                                                 1185 non-null   object
#  10  CBSA median income (2022$)                                          1185 non-null   object
#  11  Principal city median income (2022$)                                1185 non-null   object
#  12  Total population                                                    1185 non-null   object
#  13  Persons of white race, not Hispanic origin                          1185 non-null   object
#  14  Persons of black race, not Hispanic origin                          1185 non-null   object
#  15  Persons of Hispanic origin                                          1185 non-null   object
#  16  Persons of Native American race                                     1185 non-null   object
#  17  Persons of Asian race (and Pacific Islander)                        1185 non-null   object
#  18  Foreign-born                                                        1185 non-null   object
#  19  Recent immigrants (within the past 10 years)                        1185 non-null   object
#  20  Naturalized foreign-born                                            1185 non-null   object
#  21  Persons 5 years and over                                            1185 non-null   object
#  22  Persons who speak language other than English at home               1185 non-null   object
#  23  Persons who speak English not well                                  1185 non-null   object
#  24  Population 25 years and over                                        1185 non-null   object
#  25  Persons with high school degree or less                             1185 non-null   object
#  26  Persons with at least a four-year college degree                    1185 non-null   object
#  27  Civilian labor force 16 years and over                              1185 non-null   object
#  28  Unemployed                                                          1185 non-null   object
#  29  Females 16 years and over, except in armed forces                   1185 non-null   object
#  30  Females in labor force                                              1185 non-null   object
#  31  Employed persons 16 years and over                                  1185 non-null   object
#  32  Professional employees (by occupations)                             1185 non-null   object
#  33  Manufacturing employees (by industries)                             1185 non-null   object
#  34  Self-employed                                                       1185 non-null   object
#  35  Civilian population 18 years and over                               1185 non-null   object
#  36  Veterans                                                            1185 non-null   object
#  37  Disabled                                                            1185 non-null   object
#  38  Median household income                                             1174 non-null   object
#  39  Total households in sample-based data                               1185 non-null   object
#  40  Median household income for whites                                  1151 non-null   object
#  41  Total white households in sample-based data                         1185 non-null   object
#  42  Median household income for Blacks                                  864 non-null    object
#  43  Total Black households in sample-based data                         1185 non-null   object
#  44  Median household income for Hispanics                               562 non-null    object
#  45  Total Hispanic households in sample-based data                      1185 non-null   object
#  46  Median household income for Asians and Pacific Islanders            588 non-null    object
#  47  Total Asian/Pacific Islander households in sample-based data        1185 non-null   object
#  48  Per capita income                                                   1182 non-null   object
#  49  Persons for whom poverty status is determined                       1185 non-null   object
#  50  Persons in poverty                                                  1185 non-null   object
#  51  Persons 65 years and older in poverty                               1185 non-null   object
#  52  Families for whom poverty status is determined                      1185 non-null   object
#  53  Families with children in poverty                                   1185 non-null   object
#  54  White persons for whom poverty status is determined                 1185 non-null   object
#  55  Whites in poverty                                                   1185 non-null   object
#  56  Black persons for whom poverty status is determined                 1185 non-null   object
#  57  Blacks in poverty                                                   1185 non-null   object
#  58  Hispanics for whom poverty status is determined                     1185 non-null   object
#  59  Hispanics in poverty                                                1185 non-null   object
#  60  Native Americans for whom poverty status is determined              1185 non-null   object
#  61  Native Americans in poverty                                         1185 non-null   object
#  62  Asians and Pacific Islanders for whom poverty status is determined  1185 non-null   object
#  63  Asians and Pacific Islanders in poverty                             1185 non-null   object
#  64  Housing units                                                       1185 non-null   object
#  65  Vacant housing units                                                1185 non-null   object
#  66  Occupied housing units                                              1185 non-null   object
#  67  Owner-occupied housing units                                        1185 non-null   object
#  68  Renter-occupied housing units                                       1185 non-null   object
#  69  Total housing units                                                 1185 non-null   object
#  70  Housing units in multi-unit structures                              1185 non-null   object
#  71  Median home value                                                   1164 non-null   object
#  72  Median monthly contract rent                                        1156 non-null   object
#  73  Structures built more than 30 years ago                             1185 non-null   object
#  74  Household heads moved into unit less than 10 years ago              1185 non-null   object
#  75  Persons age 17 years and under                                      1185 non-null   object
#  76  Persons age 60 years and over                                       1185 non-null   object
#  77  Persons age 75 years and over                                       1185 non-null   object
#  78  Population 15 years and over                                        1185 non-null   object
#  79  Currently married (excluding separated)                             1185 non-null   object
#  80  Widowed, divorced, and separated                                    1185 non-null   object
#  81  Total families                                                      1185 non-null   object
#  82  Female-headed families with children                                1185 non-null   object
# dtypes: int64(1), object(82)
# memory usage: 777.7+ KB

# %%
relevant_data.head(10)
# Out:
# 0   Year  Tract GEOID        Tract name state            county  \
# 1   2000  42003010300  Census Tract 103    PA  Allegheny County
# 2   2000  42003020100  Census Tract 201    PA  Allegheny County
# 3   2000  42003020300  Census Tract 203    PA  Allegheny County
# 4   2000  42003030500  Census Tract 305    PA  Allegheny County
# 5   2000  42003040200  Census Tract 402    PA  Allegheny County
# 6   2000  42003040400  Census Tract 404    PA  Allegheny County
# 7   2000  42003040500  Census Tract 405    PA  Allegheny County
# 8   2000  42003040600  Census Tract 406    PA  Allegheny County
# 9   2000  42003040900  Census Tract 409    PA  Allegheny County
# 10  2000  42003050100  Census Tract 501    PA  Allegheny County
#
# 0  Place FIPS code CBSA FIPS code        cbsaname  \
# 1            61000          38300  Pittsburgh, PA
# 2            61000          38300  Pittsburgh, PA
# 3            61000          38300  Pittsburgh, PA
# 4            61000          38300  Pittsburgh, PA
# 5            61000          38300  Pittsburgh, PA
# 6            61000          38300  Pittsburgh, PA
# 7            61000          38300  Pittsburgh, PA
# 8            61000          38300  Pittsburgh, PA
# 9            61000          38300  Pittsburgh, PA
# 10           61000          38300  Pittsburgh, PA
#
# 0  Metropolitan (MSA) or micropolitan (µsa) Central or Outlying  ...  \
# 1             Metropolitan Statistical Area             Central  ...
# 2             Metropolitan Statistical Area             Central  ...
# 3             Metropolitan Statistical Area             Central  ...
# 4             Metropolitan Statistical Area             Central  ...
# 5             Metropolitan Statistical Area             Central  ...
# 6             Metropolitan Statistical Area             Central  ...
# 7             Metropolitan Statistical Area             Central  ...
# 8             Metropolitan Statistical Area             Central  ...
# 9             Metropolitan Statistical Area             Central  ...
# 10            Metropolitan Statistical Area             Central  ...
#
# 0  Structures built more than 30 years ago  \
# 1                               725.931494
# 2                                     1305
# 3                                      157
# 4                               578.685791
# 5                               516.200403
# 6                              1263.925049
# 7                                     1164
# 8                                     1036
# 9                              1204.058472
# 10                                    1141
#
# 0  Household heads moved into unit less than 10 years ago  \
# 1                                          312.500832
# 2                                                1023
# 3                                                 129
# 4                                         1047.431274
# 5                                          339.836205
# 6                                         1059.779907
# 7                                                1092
# 8                                                 949
# 9                                           893.49176
# 10                                                579
#
# 0  Persons age 17 years and under Persons age 60 years and over  \
# 1                       129.81011                    199.522448
# 2                              91                           707
# 3                              72                            36
# 4                      603.672241                    718.609863
# 5                      340.593118                    310.720155
# 6                       40.829041                    812.142883
# 7                             129                           209
# 8                             123                           202
# 9                      377.186768                    556.472961
# 10                            450                           581
#
# 0  Persons age 75 years and over Population 15 years and over  \
# 1                      77.544064                  4208.528767
# 2                            282                         4797
# 3                             11                          230
# 4                     286.844269                  2199.805664
# 5                      142.84767                  1949.987013
# 6                     484.622955                  2195.892334
# 7                             76                         2979
# 8                             80                         2140
# 9                     219.454117                  2633.449463
# 10                           218                         1746
#
# 0  Currently married (excluding separated) Widowed, divorced, and separated  \
# 1                               335.727635                       190.853009
# 2                                     3004                              889
# 3                                       16                               74
# 4                               405.779694                       796.567505
# 5                               369.423212                       260.870206
# 6                               537.878235                        396.75177
# 7                                      598                               95
# 8                                      339                              132
# 9                               711.266479                       524.142639
# 10                                     475                              636
#
# 0  Total families Female-headed families with children
# 1      148.096441                              38.0286
# 2             210                                    7
# 3              55                                   21
# 4      569.690674                            237.87085
# 5      287.688866                           119.870627
# 6      322.194397                             6.213115
# 7             230                                   22
# 8             196                                   18
# 9      535.899109                            97.970589
# 10            508                                  178
#
# [10 rows x 83 columns]

# %%
cols_to_keep = [c for c in relevant_data.columns if relevant_data[c].isna().sum() < 119]
relevant_data_nonull = relevant_data[cols_to_keep]

# %%
relevant_data_nonull.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1185 entries, 1 to 386
# Data columns (total 79 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Year                                                                1185 non-null   int64
#  1   Tract GEOID                                                         1185 non-null   object
#  2   Tract name                                                          1185 non-null   object
#  3   state                                                               1185 non-null   object
#  4   county                                                              1185 non-null   object
#  5   CBSA FIPS code                                                      1185 non-null   object
#  6   cbsaname                                                            1185 non-null   object
#  7   Metropolitan (MSA) or micropolitan (µsa)                            1185 non-null   object
#  8   Central or Outlying                                                 1185 non-null   object
#  9   CBSA median income (2022$)                                          1185 non-null   object
#  10  Principal city median income (2022$)                                1185 non-null   object
#  11  Total population                                                    1185 non-null   object
#  12  Persons of white race, not Hispanic origin                          1185 non-null   object
#  13  Persons of black race, not Hispanic origin                          1185 non-null   object
#  14  Persons of Hispanic origin                                          1185 non-null   object
#  15  Persons of Native American race                                     1185 non-null   object
#  16  Persons of Asian race (and Pacific Islander)                        1185 non-null   object
#  17  Foreign-born                                                        1185 non-null   object
#  18  Recent immigrants (within the past 10 years)                        1185 non-null   object
#  19  Naturalized foreign-born                                            1185 non-null   object
#  20  Persons 5 years and over                                            1185 non-null   object
#  21  Persons who speak language other than English at home               1185 non-null   object
#  22  Persons who speak English not well                                  1185 non-null   object
#  23  Population 25 years and over                                        1185 non-null   object
#  24  Persons with high school degree or less                             1185 non-null   object
#  25  Persons with at least a four-year college degree                    1185 non-null   object
#  26  Civilian labor force 16 years and over                              1185 non-null   object
#  27  Unemployed                                                          1185 non-null   object
#  28  Females 16 years and over, except in armed forces                   1185 non-null   object
#  29  Females in labor force                                              1185 non-null   object
#  30  Employed persons 16 years and over                                  1185 non-null   object
#  31  Professional employees (by occupations)                             1185 non-null   object
#  32  Manufacturing employees (by industries)                             1185 non-null   object
#  33  Self-employed                                                       1185 non-null   object
#  34  Civilian population 18 years and over                               1185 non-null   object
#  35  Veterans                                                            1185 non-null   object
#  36  Disabled                                                            1185 non-null   object
#  37  Median household income                                             1174 non-null   object
#  38  Total households in sample-based data                               1185 non-null   object
#  39  Median household income for whites                                  1151 non-null   object
#  40  Total white households in sample-based data                         1185 non-null   object
#  41  Total Black households in sample-based data                         1185 non-null   object
#  42  Total Hispanic households in sample-based data                      1185 non-null   object
#  43  Total Asian/Pacific Islander households in sample-based data        1185 non-null   object
#  44  Per capita income                                                   1182 non-null   object
#  45  Persons for whom poverty status is determined                       1185 non-null   object
#  46  Persons in poverty                                                  1185 non-null   object
#  47  Persons 65 years and older in poverty                               1185 non-null   object
#  48  Families for whom poverty status is determined                      1185 non-null   object
#  49  Families with children in poverty                                   1185 non-null   object
#  50  White persons for whom poverty status is determined                 1185 non-null   object
#  51  Whites in poverty                                                   1185 non-null   object
#  52  Black persons for whom poverty status is determined                 1185 non-null   object
#  53  Blacks in poverty                                                   1185 non-null   object
#  54  Hispanics for whom poverty status is determined                     1185 non-null   object
#  55  Hispanics in poverty                                                1185 non-null   object
#  56  Native Americans for whom poverty status is determined              1185 non-null   object
#  57  Native Americans in poverty                                         1185 non-null   object
#  58  Asians and Pacific Islanders for whom poverty status is determined  1185 non-null   object
#  59  Asians and Pacific Islanders in poverty                             1185 non-null   object
#  60  Housing units                                                       1185 non-null   object
#  61  Vacant housing units                                                1185 non-null   object
#  62  Occupied housing units                                              1185 non-null   object
#  63  Owner-occupied housing units                                        1185 non-null   object
#  64  Renter-occupied housing units                                       1185 non-null   object
#  65  Total housing units                                                 1185 non-null   object
#  66  Housing units in multi-unit structures                              1185 non-null   object
#  67  Median home value                                                   1164 non-null   object
#  68  Median monthly contract rent                                        1156 non-null   object
#  69  Structures built more than 30 years ago                             1185 non-null   object
#  70  Household heads moved into unit less than 10 years ago              1185 non-null   object
#  71  Persons age 17 years and under                                      1185 non-null   object
#  72  Persons age 60 years and over                                       1185 non-null   object
#  73  Persons age 75 years and over                                       1185 non-null   object
#  74  Population 15 years and over                                        1185 non-null   object
#  75  Currently married (excluding separated)                             1185 non-null   object
#  76  Widowed, divorced, and separated                                    1185 non-null   object
#  77  Total families                                                      1185 non-null   object
#  78  Female-headed families with children                                1185 non-null   object
# dtypes: int64(1), object(78)
# memory usage: 740.6+ KB

# %%
relevant_data_nonull.to_excel("clean_middleneighborhood_data.xlsx")

# %%
relevant_data_nonull.sample(10)
# Out:
# 0    Year  Tract GEOID         Tract name state            county  \
# 6    2022  42003040200   Census Tract 402    PA  Allegheny County
# 380  2022  42003565300  Census Tract 5653    PA  Allegheny County
# 25   2012  42003080700   Census Tract 807    PA  Allegheny County
# 163  2000  42003429400  Census Tract 4294    PA  Allegheny County
# 90   2000  42003261200  Census Tract 2612    PA  Allegheny County
# 98   2022  42003320700  Census Tract 3207    PA  Allegheny County
# 59   2012  42003141300  Census Tract 1413    PA  Allegheny County
# 114  2000  42003403500  Census Tract 4035    PA  Allegheny County
# 68   2022  42003191400  Census Tract 1914    PA  Allegheny County
# 259  2000  42003480200  Census Tract 4802    PA  Allegheny County
#
# 0   CBSA FIPS code        cbsaname Metropolitan (MSA) or micropolitan (µsa)  \
# 6            38300  Pittsburgh, PA            Metropolitan Statistical Area
# 380          38300  Pittsburgh, PA            Metropolitan Statistical Area
# 25           38300  Pittsburgh, PA            Metropolitan Statistical Area
# 163          38300  Pittsburgh, PA            Metropolitan Statistical Area
# 90           38300  Pittsburgh, PA            Metropolitan Statistical Area
# 98           38300  Pittsburgh, PA            Metropolitan Statistical Area
# 59           38300  Pittsburgh, PA            Metropolitan Statistical Area
# 114          38300  Pittsburgh, PA            Metropolitan Statistical Area
# 68           38300  Pittsburgh, PA            Metropolitan Statistical Area
# 259          38300  Pittsburgh, PA            Metropolitan Statistical Area
#
# 0   Central or Outlying CBSA median income (2022$)  ...  \
# 6               Central                      71283  ...
# 380             Central                      71283  ...
# 25              Central                      50182  ...
# 163             Central                      37467  ...
# 90              Central                      37467  ...
# 98              Central                      71283  ...
# 59              Central                      50182  ...
# 114             Central                      37467  ...
# 68              Central                      71283  ...
# 259             Central                      37467  ...
#
# 0   Structures built more than 30 years ago  \
# 6                                       457
# 380                                     494
# 25                                     1161
# 163                             1788.860088
# 90                               465.377104
# 98                                      795
# 59                                     2389
# 114                             2332.416971
# 68                                     1722
# 259                             1141.122174
#
# 0   Household heads moved into unit less than 10 years ago  \
# 6                                                  274
# 380                                                132
# 25                                                 868
# 163                                         862.363351
# 90                                          178.179851
# 98                                                 354
# 59                                                1667
# 114                                         1129.96158
# 68                                                1112
# 259                                         595.067949
#
# 0   Persons age 17 years and under Persons age 60 years and over  \
# 6                              133                           231
# 380                            223                           423
# 25                              78                           160
# 163                     927.006393                   1224.520737
# 90                      201.893552                    271.672772
# 98                             382                           393
# 59                             726                          1104
# 114                    1087.548499                    967.596763
# 68                             173                           482
# 259                     714.455108                    828.160769
#
# 0   Persons age 75 years and over Population 15 years and over  \
# 6                              83                         1710
# 380                           124                         1040
# 25                             75                         1532
# 163                    518.317701                  3861.497439
# 90                     106.886228                   923.166938
# 98                            102                         1542
# 59                            575                         4530
# 114                    373.929606                  4020.681058
# 68                            145                         2284
# 259                     258.49606                  3000.641512
#
# 0   Currently married (excluding separated) Widowed, divorced, and separated  \
# 6                                       183                              152
# 380                                     513                              221
# 25                                      485                              138
# 163                             2330.900324                       674.192997
# 90                               539.946188                       161.699103
# 98                                      816                              225
# 59                                     1977                              664
# 114                             1813.171627                       916.245139
# 68                                      604                              349
# 259                             1787.273289                       446.235034
#
# 0   Total families Female-headed families with children
# 6              165                                   48
# 380            312                                   27
# 25             280                                   14
# 163    1333.853261                            65.992856
# 90      316.002288                            33.984249
# 98             460                                   21
# 59            1056                                   31
# 114    1294.066898                           175.186584
# 68             378                                   69
# 259    1060.450612                            54.565765
#
# [10 rows x 79 columns]

# %%
import geopandas as gpd

tracts = gpd.read_file("../CensusTracts/2020/tl_2020_42_tract.shp")

# %%
tracts['GEOID'] = tracts['GEOID'].astype(int)

# %%
relevant_data_nonull['Tract GEOID'] = relevant_data_nonull['Tract GEOID'].astype(int)
# Out:
# C:\Users\quint\AppData\Local\Temp\ipykernel_2924\4198718843.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   relevant_data_nonull['Tract GEOID'] = relevant_data_nonull['Tract GEOID'].astype(int)

# %%
joined_data = relevant_data_nonull.merge(tracts, left_on="Tract GEOID", right_on="GEOID")

# %%
relevant_data_nonull.shape
# Out:
# (1185, 79)

# %%
joined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1113 entries, 0 to 1112
# Data columns (total 92 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Year                                                                1113 non-null   int64
#  1   Tract GEOID                                                         1113 non-null   int64
#  2   Tract name                                                          1113 non-null   object
#  3   state                                                               1113 non-null   object
#  4   county                                                              1113 non-null   object
#  5   CBSA FIPS code                                                      1113 non-null   object
#  6   cbsaname                                                            1113 non-null   object
#  7   Metropolitan (MSA) or micropolitan (µsa)                            1113 non-null   object
#  8   Central or Outlying                                                 1113 non-null   object
#  9   CBSA median income (2022$)                                          1113 non-null   object
#  10  Principal city median income (2022$)                                1113 non-null   object
#  11  Total population                                                    1113 non-null   object
#  12  Persons of white race, not Hispanic origin                          1113 non-null   object
#  13  Persons of black race, not Hispanic origin                          1113 non-null   object
#  14  Persons of Hispanic origin                                          1113 non-null   object
#  15  Persons of Native American race                                     1113 non-null   object
#  16  Persons of Asian race (and Pacific Islander)                        1113 non-null   object
#  17  Foreign-born                                                        1113 non-null   object
#  18  Recent immigrants (within the past 10 years)                        1113 non-null   object
#  19  Naturalized foreign-born                                            1113 non-null   object
#  20  Persons 5 years and over                                            1113 non-null   object
#  21  Persons who speak language other than English at home               1113 non-null   object
#  22  Persons who speak English not well                                  1113 non-null   object
#  23  Population 25 years and over                                        1113 non-null   object
#  24  Persons with high school degree or less                             1113 non-null   object
#  25  Persons with at least a four-year college degree                    1113 non-null   object
#  26  Civilian labor force 16 years and over                              1113 non-null   object
#  27  Unemployed                                                          1113 non-null   object
#  28  Females 16 years and over, except in armed forces                   1113 non-null   object
#  29  Females in labor force                                              1113 non-null   object
#  30  Employed persons 16 years and over                                  1113 non-null   object
#  31  Professional employees (by occupations)                             1113 non-null   object
#  32  Manufacturing employees (by industries)                             1113 non-null   object
#  33  Self-employed                                                       1113 non-null   object
#  34  Civilian population 18 years and over                               1113 non-null   object
#  35  Veterans                                                            1113 non-null   object
#  36  Disabled                                                            1113 non-null   object
#  37  Median household income                                             1102 non-null   object
#  38  Total households in sample-based data                               1113 non-null   object
#  39  Median household income for whites                                  1084 non-null   object
#  40  Total white households in sample-based data                         1113 non-null   object
#  41  Total Black households in sample-based data                         1113 non-null   object
#  42  Total Hispanic households in sample-based data                      1113 non-null   object
#  43  Total Asian/Pacific Islander households in sample-based data        1113 non-null   object
#  44  Per capita income                                                   1110 non-null   object
#  45  Persons for whom poverty status is determined                       1113 non-null   object
#  46  Persons in poverty                                                  1113 non-null   object
#  47  Persons 65 years and older in poverty                               1113 non-null   object
#  48  Families for whom poverty status is determined                      1113 non-null   object
#  49  Families with children in poverty                                   1113 non-null   object
#  50  White persons for whom poverty status is determined                 1113 non-null   object
#  51  Whites in poverty                                                   1113 non-null   object
#  52  Black persons for whom poverty status is determined                 1113 non-null   object
#  53  Blacks in poverty                                                   1113 non-null   object
#  54  Hispanics for whom poverty status is determined                     1113 non-null   object
#  55  Hispanics in poverty                                                1113 non-null   object
#  56  Native Americans for whom poverty status is determined              1113 non-null   object
#  57  Native Americans in poverty                                         1113 non-null   object
#  58  Asians and Pacific Islanders for whom poverty status is determined  1113 non-null   object
#  59  Asians and Pacific Islanders in poverty                             1113 non-null   object
#  60  Housing units                                                       1113 non-null   object
#  61  Vacant housing units                                                1113 non-null   object
#  62  Occupied housing units                                              1113 non-null   object
#  63  Owner-occupied housing units                                        1113 non-null   object
#  64  Renter-occupied housing units                                       1113 non-null   object
#  65  Total housing units                                                 1113 non-null   object
#  66  Housing units in multi-unit structures                              1113 non-null   object
#  67  Median home value                                                   1093 non-null   object
#  68  Median monthly contract rent                                        1085 non-null   object
#  69  Structures built more than 30 years ago                             1113 non-null   object
#  70  Household heads moved into unit less than 10 years ago              1113 non-null   object
#  71  Persons age 17 years and under                                      1113 non-null   object
#  72  Persons age 60 years and over                                       1113 non-null   object
#  73  Persons age 75 years and over                                       1113 non-null   object
#  74  Population 15 years and over                                        1113 non-null   object
#  75  Currently married (excluding separated)                             1113 non-null   object
#  76  Widowed, divorced, and separated                                    1113 non-null   object
#  77  Total families                                                      1113 non-null   object
#  78  Female-headed families with children                                1113 non-null   object
#  79  STATEFP                                                             1113 non-null   object
#  80  COUNTYFP                                                            1113 non-null   object
#  81  TRACTCE                                                             1113 non-null   object
#  82  GEOID                                                               1113 non-null   int64
#  83  NAME                                                                1113 non-null   object
#  84  NAMELSAD                                                            1113 non-null   object
#  85  MTFCC                                                               1113 non-null   object
#  86  FUNCSTAT                                                            1113 non-null   object
#  87  ALAND                                                               1113 non-null   int64
#  88  AWATER                                                              1113 non-null   int64
#  89  INTPTLAT                                                            1113 non-null   object
#  90  INTPTLON                                                            1113 non-null   object
#  91  geometry                                                            1113 non-null   geometry
# dtypes: geometry(1), int64(5), object(86)
# memory usage: 800.1+ KB

# %%
joined_data.to_excel("clean_middleneighborhood_data_spatial.xlsx")

# %%
joined_again = tracts.merge(relevant_data_nonull, right_on="Tract GEOID", left_on="GEOID")
joined_again["GEOID"] = joined_again["GEOID"].astype(str)

# %%
joined_again.drop(columns=['Tract GEOID']).to_file("census_tracts.geojson", driver="GeoJSON")
